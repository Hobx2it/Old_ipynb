# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                         наименование    цена
# 0     Клиника Благодатная на проспекте Юрия Гагарина
# 2                                            Ксеомин  290 р.
# 3                      Дезир на проспекте Пархоменко
# 5     Коррекция морщин препаратом Ксеомин, 1 единица  300 р.
# 6                         GMTClinic на Льва Толстого
# ...                                              ...     ...
# 1069         Введение препарата Релатокс (1 единица)  350 р.
# 1070              Асмедия на проспекте Чернышевского
# 1072                     Ботулотоксин Relatox (1 ед)  280 р.
# 1073               Альбатрос на Искровском проспекте
# 1075                                   Релатокс 1 ед  300 р.
#
# [726 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                               Центр  \
# 0    Клиника Благодатная на проспекте Юрия Гагарина
# 1                     Дезир на проспекте Пархоменко
# 2                        GMTClinic на Льва Толстого
# 3                        GMTClinic на Льва Толстого
# 4                              Mediderm на Гжатской
# ..                                              ...
# 371    Клиника эстетической хирургии и косметологии
# 372            Skin Lazer Med на проспекте Энгельса
# 373                    Skin Lazer Med на Сытнинской
# 374              Асмедия на проспекте Чернышевского
# 375               Альбатрос на Искровском проспекте
#
#                                               Услуга    Цена
# 0                                            Ксеомин  290 р.
# 1     Коррекция морщин препаратом Ксеомин, 1 единица  300 р.
# 2                                       Ксеомин 1 ед  380 р.
# 3    Лечение гипергидроза (от 80 ед.) , Ксеомин 1 ед  300 р.
# 4                                      Xeomin (1ед.)  280 р.
# ..                                               ...     ...
# 371                                         Релатокс  335 р.
# 372          Введение препарата Релатокс (1 единица)  350 р.
# 373          Введение препарата Релатокс (1 единица)  350 р.
# 374                      Ботулотоксин Relatox (1 ед)  280 р.
# 375                                    Релатокс 1 ед  300 р.
#
# [376 rows x 3 columns]

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new[['Центр', 'Цена', 'Услуга']].to_excel('цены_' + file_excel, index=False)
