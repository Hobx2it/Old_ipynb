# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                          наименование      цена
# 0                               ИнтраМед на Савушкина
# 2   Интенсивное наблюдение анестезиолога (индивиду...   5000 р.
# 3                             Скандинавия на Ильюшина
# 5    Наблюдение анестезиологом-реаниматологом (1 час)   1900 р.
# 6                           Согаз на Малой Конюшенной
# 8   Послеоперационное наблюдение с 09. 00-21. 00 -...    990 р.
# 9                    TTLife на Лабораторном проспекте
# 11  Наблюдение врачом Анестезиологом - реаниматоло...   2200 р.
# 12                      ЛамиМед на проспекте Культуры
# 14  интенсивное наблюдение анестезиолога (индивиду...   5000 р.
# 15                            ФГБУ КДЦ с поликлиникой
# 17  Суточное наблюдение врачом-анестезиологом-реан...   2800 р.
# 18     Городская больница №9 на Крестовском проспекте
# 20  пребывания (лечения) в палате интенсивной терр...  15000 р.

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                             Центр  \
# 0                           ИнтраМед на Савушкина
# 1                         Скандинавия на Ильюшина
# 2                       Согаз на Малой Конюшенной
# 3                TTLife на Лабораторном проспекте
# 4                   ЛамиМед на проспекте Культуры
# 5                         ФГБУ КДЦ с поликлиникой
# 6  Городская больница №9 на Крестовском проспекте
#
#                                               Услуга      Цена
# 0  Интенсивное наблюдение анестезиолога (индивиду...   5000 р.
# 1   Наблюдение анестезиологом-реаниматологом (1 час)   1900 р.
# 2  Послеоперационное наблюдение с 09. 00-21. 00 -...    990 р.
# 3  Наблюдение врачом Анестезиологом - реаниматоло...   2200 р.
# 4  интенсивное наблюдение анестезиолога (индивиду...   5000 р.
# 5  Суточное наблюдение врачом-анестезиологом-реан...   2800 р.
# 6  пребывания (лечения) в палате интенсивной терр...  15000 р.

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new[['Центр', 'Цена', 'Услуга']].to_excel('цены_' + file_excel, index=False)
