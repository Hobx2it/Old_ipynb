# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
arr = [x for x in np.arange(-1000, 1000, 0.01) if x ** 2 > x ** 3]

# %%
lst = np.random.randint(-1000, 1000, 10000)

lst.cumsum()#.plot()

fig = plt.figure()

ax = fig.add_subplot(1,1,1)

ax.plot(lst.cumsum())
