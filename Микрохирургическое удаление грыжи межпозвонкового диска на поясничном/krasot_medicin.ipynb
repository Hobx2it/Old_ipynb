# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                          наименование       цена
# 0                         СМТ на Московском проспекте
# 2                    Эндоскопическая микродискэктомия  100000 р.
# 3                    Эндоскопическая микродискэктомия  100000 р.
# 4                    Эндоскопическая микродискэктомия  100000 р.
# 5                           СМТ на Римского-Корсакова
# 7                    Эндоскопическая микродискэктомия  100000 р.
# 8                    Эндоскопическая микродискэктомия  100000 р.
# 9                    Эндоскопическая микродискэктомия  100000 р.
# 10                  СМ-Клиника на Дунайском проспекте
# 12  Микродискэктомия поясничная на одном уровне* I...   49500 р.
# 13                  СМ-Клиника на проспекте Ударников
# 15  Микродискэктомия поясничная на одном уровне* I...   49500 р.
# 16                     СМ-Клиника на Маршала Захарова
# 18  Микродискэктомия поясничная на одном уровне* I...   49500 р.
# 19  Клиника им. Н.И. Пирогова на Васильевском Острове
# 21  Чрескожное эндоскопическое удаление грыжи межп...  156500 р.
# 22  Чрескожное эндоскопическое удаление грыжи межп...  156500 р.
# 23  Чрескожное эндоскопическое удаление грыжи межп...  156500 р.
# 24                     СМ-Клиника на Выборгском шоссе
# 26  Микродискэктомия поясничная на одном уровне* I...   49500 р.
# 27                           СМТ на Валерия Гаврилина
# 29                   Эндоскопическая микродискэктомия  100000 р.
# 30                   Эндоскопическая микродискэктомия  100000 р.
# 31                   Эндоскопическая микродискэктомия  100000 р.
# 32                   Американская медицинская клиника
# 33  Микродискэктомия В пакет услуги входит: консул...   89300 р.
# 34  Микродискэктомия В пакет услуги входит: консул...   89300 р.
# 35  Микродискэктомия В пакет услуги входит: консул...   89300 р.
# 36                    Адмиралтейские Верфи на Садовой
# 38  Микродискэктомия шейного отдела 3 степени слож...   50000 р.
# 39  Микродискэктомия пояснично-крестцового отдела ...   35000 р.
# 40                           MedSwiss на Гаккелевской
# 42  Микродискэктомия, пояснично-крестцовый отдел, ...   21200 р.
# 43                       Клиника имени Петра Великого
# 45               Микродискэктомия, шейный, эндоскопия   44000 р.
# 46                               Онкоцентр в Песочном
# 48  Микрохирургическое удаление грыжи межпозвонков...  125000 р.
# 49                             ФМИЦ им. В.А. Алмазова
# 51                                   Микродискэктомия   40000 р.
# 52                         НИИ СП им. И.И. Джанелидзе
# 54                 Микродискэктомия, поясничный отдел   20000 р.
# 55               Микродискэктомия, шейный, эндоскопия   25000 р.
# 56         Военно-медицинская академия им. С.М.Кирова
# 58                     Микрохирургическая дискэктомия   28700 р.
# 59                 Институт мозга им. Н.П. Бехтеревой
# 61                     Микрохирургическая дискэктомия   70500 р.
# 62                                показать еще 1 цену
# 63  ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Ак. Лебедева
# 65  Микродискэктомия шейного, грудного и пояснично...   70000 р.
# 66       ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Оптиков
# 68  Микродискэктомия шейного, грудного и пояснично...   70000 р.
# 69               Городская больница №40 в Сестрорецке
# 71  Удаление грыжи межпозвонкового диска (микродек...   90000 р.
# 72            Дорожная клиническая больница ОАО «РЖД»
# 74       Микродискэктомия с сохранением желтой связки   40000 р.
# 75          Городская Мариинская больница на Литейном
# 77                                   Микродискэктомия   35000 р.
# 78                                   Микродискэктомия   35000 р.
# 79                                   Микродискэктомия   35000 р.
# 80                                   Микродискэктомия   35000 р.

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                                 Центр  \
# 0                         СМТ на Московском проспекте
# 1                         СМТ на Московском проспекте
# 2                         СМТ на Московском проспекте
# 3                           СМТ на Римского-Корсакова
# 4                           СМТ на Римского-Корсакова
# 5                           СМТ на Римского-Корсакова
# 6                   СМ-Клиника на Дунайском проспекте
# 7                   СМ-Клиника на проспекте Ударников
# 8                      СМ-Клиника на Маршала Захарова
# 9   Клиника им. Н.И. Пирогова на Васильевском Острове
# 10  Клиника им. Н.И. Пирогова на Васильевском Острове
# 11  Клиника им. Н.И. Пирогова на Васильевском Острове
# 12                     СМ-Клиника на Выборгском шоссе
# 13                           СМТ на Валерия Гаврилина
# 14                           СМТ на Валерия Гаврилина
# 15                           СМТ на Валерия Гаврилина
# 16                   Американская медицинская клиника
# 17                   Американская медицинская клиника
# 18                   Американская медицинская клиника
# 19                    Адмиралтейские Верфи на Садовой
# 20                    Адмиралтейские Верфи на Садовой
# 21                           MedSwiss на Гаккелевской
# 22                       Клиника имени Петра Великого
# 23                               Онкоцентр в Песочном
# 24                             ФМИЦ им. В.А. Алмазова
# 25                         НИИ СП им. И.И. Джанелидзе
# 26                         НИИ СП им. И.И. Джанелидзе
# 27         Военно-медицинская академия им. С.М.Кирова
# 28                 Институт мозга им. Н.П. Бехтеревой
# 29  ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Ак. Лебедева
# 30       ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Оптиков
# 31               Городская больница №40 в Сестрорецке
# 32            Дорожная клиническая больница ОАО «РЖД»
# 33          Городская Мариинская больница на Литейном
# 34          Городская Мариинская больница на Литейном
# 35          Городская Мариинская больница на Литейном
# 36          Городская Мариинская больница на Литейном
#
#                                                Услуга       Цена
# 0                    Эндоскопическая микродискэктомия  100000 р.
# 1                    Эндоскопическая микродискэктомия  100000 р.
# 2                    Эндоскопическая микродискэктомия  100000 р.
# 3                    Эндоскопическая микродискэктомия  100000 р.
# 4                    Эндоскопическая микродискэктомия  100000 р.
# 5                    Эндоскопическая микродискэктомия  100000 р.
# 6   Микродискэктомия поясничная на одном уровне* I...   49500 р.
# 7   Микродискэктомия поясничная на одном уровне* I...   49500 р.
# 8   Микродискэктомия поясничная на одном уровне* I...   49500 р.
# 9   Чрескожное эндоскопическое удаление грыжи межп...  156500 р.
# 10  Чрескожное эндоскопическое удаление грыжи межп...  156500 р.
# 11  Чрескожное эндоскопическое удаление грыжи межп...  156500 р.
# 12  Микродискэктомия поясничная на одном уровне* I...   49500 р.
# 13                   Эндоскопическая микродискэктомия  100000 р.
# 14                   Эндоскопическая микродискэктомия  100000 р.
# 15                   Эндоскопическая микродискэктомия  100000 р.
# 16  Микродискэктомия В пакет услуги входит: консул...   89300 р.
# 17  Микродискэктомия В пакет услуги входит: консул...   89300 р.
# 18  Микродискэктомия В пакет услуги входит: консул...   89300 р.
# 19  Микродискэктомия шейного отдела 3 степени слож...   50000 р.
# 20  Микродискэктомия пояснично-крестцового отдела ...   35000 р.
# 21  Микродискэктомия, пояснично-крестцовый отдел, ...   21200 р.
# 22               Микродискэктомия, шейный, эндоскопия   44000 р.
# 23  Микрохирургическое удаление грыжи межпозвонков...  125000 р.
# 24                                   Микродискэктомия   40000 р.
# 25                 Микродискэктомия, поясничный отдел   20000 р.
# 26               Микродискэктомия, шейный, эндоскопия   25000 р.
# 27                     Микрохирургическая дискэктомия   28700 р.
# 28                     Микрохирургическая дискэктомия   70500 р.
# 29  Микродискэктомия шейного, грудного и пояснично...   70000 р.
# 30  Микродискэктомия шейного, грудного и пояснично...   70000 р.
# 31  Удаление грыжи межпозвонкового диска (микродек...   90000 р.
# 32       Микродискэктомия с сохранением желтой связки   40000 р.
# 33                                   Микродискэктомия   35000 р.
# 34                                   Микродискэктомия   35000 р.
# 35                                   Микродискэктомия   35000 р.
# 36                                   Микродискэктомия   35000 р.

# %%
data_new['Центр'] = data_new['Центр'].apply(lambda x: x[:x.find(' на ')])
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
