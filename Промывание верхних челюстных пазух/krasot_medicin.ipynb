# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование    цена
# 0                              МЦ Династия на Репищева
# 2      Промывание верхнечелюстной пазухи через катетер  750 р.
# 3                          АрсВита на проспекте Тореза
# 5    Промывание верхнечелюстной пазухи через соусть...  750 р.
# 6                                МЦ Династия на Ленина
# ..                                                 ...     ...
# 172       Промывание оперированных пазух через соустье  850 р.
# 173                 КДЦ им. Г.И. Турнера на Лахтинской
# 175  Промывание верхнечелюстной пазухи носа (после ...  590 р.
# 176                               МСЧ №70 на Комсомола
# 178             Промывание верхнечелюстной пазухи носа  700 р.
#
# [120 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                           Центр  \
# 0                       МЦ Династия на Репищева
# 1                   АрсВита на проспекте Тореза
# 2                         МЦ Династия на Ленина
# 3                       Скандинавия на Парадной
# 4                             Медика на Бадаева
# ..                                          ...
# 56                    КБ №122 им. Л.Г. Соколова
# 57  ЛДЦ МИБС им. С.М. Березина на 6-й Советской
# 58        ЛДЦ МИБС им. С.М. Березина на Есенина
# 59           КДЦ им. Г.И. Турнера на Лахтинской
# 60                         МСЧ №70 на Комсомола
#
#                                                Услуга     Цена
# 0     Промывание верхнечелюстной пазухи через катетер   750 р.
# 1   Промывание верхнечелюстной пазухи через соусть...   750 р.
# 2     Промывание верхнечелюстной пазухи через катетер   750 р.
# 3   Промывание одной верхнечелюстной пазухи через ...  1700 р.
# 4   Промывание придаточных пазух носа через катете...  1000 р.
# ..                                                ...      ...
# 56  Промывание верхнечелюстных пазух через соустье...   520 р.
# 57       Промывание оперированных пазух через соустье   850 р.
# 58       Промывание оперированных пазух через соустье   850 р.
# 59  Промывание верхнечелюстной пазухи носа (после ...   590 р.
# 60             Промывание верхнечелюстной пазухи носа   700 р.
#
# [61 rows x 3 columns]

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new[['Центр', 'Цена', 'Услуга']].to_excel('цены_' + file_excel, index=False)
