# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование    цена
# 0                       САН Клиник в Шведском переулке
# 2                    Инъекция Релатокс-Relatox (1 ед.)  350 р.
# 3                    Доктор Дент на проспекте Энгельса
# 5    Внутримышечное введение Релатокс 1 (одна) единица  320 р.
# 6                     ДМЦ Гайде на Лиговском проспекте
# ..                                                 ...     ...
# 225                               Релатокс (1 единица)  350 р.
# 226                               Инкона на Купчинской
# 228  Ботулинотерапия (Ботокс, Ксеомин, Релатокс) / ...  320 р.
# 229                          КБ №122 им. Л.Г. Соколова
# 231  Лечение мышечного гипертонуса с использованием...  240 р.
#
# [156 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                               Центр  \
# 0                    САН Клиник в Шведском переулке
# 1                 Доктор Дент на проспекте Энгельса
# 2                  ДМЦ Гайде на Лиговском проспекте
# 3                  ДМЦ Гайде на Лиговском проспекте
# 4                            МЦ Гайде на Херсонской
# ..                                              ...
# 75                           АБА-клиника на Ленской
# 76  Бенуа Медикал Спа на Каменностровском проспекте
# 77               Арт Бьюти на проспекте Просвещения
# 78                             Инкона на Купчинской
# 79                        КБ №122 им. Л.Г. Соколова
#
#                                                Услуга    Цена
# 0                   Инъекция Релатокс-Relatox (1 ед.)  350 р.
# 1   Внутримышечное введение Релатокс 1 (одна) единица  320 р.
# 2                     Введение препарата Релатокс 1ед  350 р.
# 3   Введение препарата Релатокс при лечении гиперг...  280 р.
# 4                     Введение препарата Релатокс 1ед  350 р.
# ..                                                ...     ...
# 75                                     Релатокс (1ед)  310 р.
# 76                                    Relatox (1 ед.)  270 р.
# 77                               Релатокс (1 единица)  350 р.
# 78  Ботулинотерапия (Ботокс, Ксеомин, Релатокс) / ...  320 р.
# 79  Лечение мышечного гипертонуса с использованием...  240 р.
#
# [80 rows x 3 columns]

# %%
data_new['Центр'] = data_new['Центр'].apply(lambda x: x[:x.find(' на ')])
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
