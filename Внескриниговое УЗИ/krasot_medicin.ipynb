# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование     цена
# 0                              МЦ Династия на Репищева
# 2    Допплерометрия маточно-плацентарного кровотока...  1200 р.
# 3                    СМ-Клиника на Дунайском проспекте
# 5                    УЗИ на ранних сроках беременности  2100 р.
# 6                    СМ-Клиника на проспекте Ударников
# ..                                                 ...      ...
# 383      Допплерография фетоплацентарная в амбулатории  2050 р.
# 384                                 ЛенМед на Гаврской
# 386                                      Доплерометрия  1000 р.
# 387                                  МЦ на Колокольной
# 389                    Допплерография фетоплацентарная  1200 р.
#
# [260 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                  Центр  \
# 0              МЦ Династия на Репищева
# 1    СМ-Клиника на Дунайском проспекте
# 2    СМ-Клиника на проспекте Ударников
# 3       СМ-Клиника на Маршала Захарова
# 4         АрсВита на Краснопутиловской
# ..                                 ...
# 125                XXI век на Гастелло
# 126               XXI век на Сикейроса
# 127          XXI век на проспекте КИМа
# 128                 ЛенМед на Гаврской
# 129                  МЦ на Колокольной
#
#                                                 Услуга     Цена
# 0    Допплерометрия маточно-плацентарного кровотока...  1200 р.
# 1                    УЗИ на ранних сроках беременности  2100 р.
# 2                    УЗИ на ранних сроках беременности  2100 р.
# 3                    УЗИ на ранних сроках беременности  2100 р.
# 4                         Допплерометрия сосудов плода  1500 р.
# ..                                                 ...      ...
# 125      Допплерография фетоплацентарная в амбулатории  2050 р.
# 126      Допплерография фетоплацентарная в амбулатории  2050 р.
# 127      Допплерография фетоплацентарная в амбулатории  2050 р.
# 128                                      Доплерометрия  1000 р.
# 129                    Допплерография фетоплацентарная  1200 р.
#
# [130 rows x 3 columns]

# %%
data_new['Центр'] = data_new['Центр'].apply(lambda x: x[:x.find(' на ')])
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
