# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование     цена
# 0                                Мединеф на Боткинской
# 2    Проведение сеанса гирудотерапии (без стоимости...  1500 р.
# 3                              Скандинавия на Ильюшина
# 5        Проведение сеанса гирудотерапии (до 3 пиявок)  2580 р.
# 6                               МЦ Гайде на Херсонской
# ..                                                 ...      ...
# 437  Постановка пиявок (гирудотерапия) с учетом сто...  1450 р.
# 438            Дорожная клиническая больница ОАО «РЖД»
# 440                                      Гирудотерапия  1400 р.
# 441          НИИ детских инфекций на Профессора Попова
# 443                           Гирудотерапия (взрослая)  1700 р.
#
# [296 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                                  Центр  \
# 0                                Мединеф на Боткинской
# 1                              Скандинавия на Ильюшина
# 2                               МЦ Гайде на Херсонской
# 3                     ДМЦ Гайде на Лиговском проспекте
# 4                               Клиника на Театральной
# ..                                                 ...
# 143  ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Ак. Лебедева
# 144       ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Оптиков
# 145                          КБ №122 им. Л.Г. Соколова
# 146            Дорожная клиническая больница ОАО «РЖД»
# 147          НИИ детских инфекций на Профессора Попова
#
#                                                 Услуга     Цена
# 0    Проведение сеанса гирудотерапии (без стоимости...  1500 р.
# 1        Проведение сеанса гирудотерапии (до 3 пиявок)  2580 р.
# 2                                  Сеанс гирудотерапии  1600 р.
# 3                                  Сеанс гирудотерапии  1600 р.
# 4    Лечебный сеанс гирудотерапии (без стоимости ра...   900 р.
# ..                                                 ...      ...
# 143                         Гирудотерапия, 1 процедура  1650 р.
# 144                         Гирудотерапия, 1 процедура  1650 р.
# 145  Постановка пиявок (гирудотерапия) с учетом сто...  1450 р.
# 146                                      Гирудотерапия  1400 р.
# 147                           Гирудотерапия (взрослая)  1700 р.
#
# [148 rows x 3 columns]

# %%
data_new['Центр'] = data_new['Центр'].apply(lambda x: x[:x.find(' на ')])
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
