# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование     цена
# 0                              МЦ Династия на Репищева
# 2                    Трансдермальная электростимуляция  1800 р.
# 3                                 Клиника Доктора Пеля
# 5         Транскраниальная электростимуляция (1 сеанс)   350 р.
# 6       Клиника Благодатная на проспекте Юрия Гагарина
# ..                                                 ...      ...
# 670  Миоэлектростимуляция (электростимуляция аппара...   580 р.
# 671         Детская поликлиника №35 в Детском переулке
# 673  Миоэлектростимуляция (электростимуляция аппара...   580 р.
# 674                Детская поликлиника №47 на Костюшко
# 676  Миоэлектростимуляция (электростимуляция аппара...   580 р.
#
# [493 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                                Центр  \
# 0                            МЦ Династия на Репищева
# 1                               Клиника Доктора Пеля
# 2     Клиника Благодатная на проспекте Юрия Гагарина
# 3                      Дезир на проспекте Пархоменко
# 4                   ДМЦ Гайде на Лиговском проспекте
# ..                                               ...
# 304  ДГБ № 2 Св. Марии Магдалины на 2-ой линии В. О.
# 305       Роддом №13 Санкт-Петербурга на Костромской
# 306   Детская поликлиника №35 на Ленинском проспекте
# 307       Детская поликлиника №35 в Детском переулке
# 308              Детская поликлиника №47 на Костюшко
#
#                                                 Услуга     Цена
# 0                    Трансдермальная электростимуляция  1800 р.
# 1         Транскраниальная электростимуляция (1 сеанс)   350 р.
# 2             Внутритканевая электро-стимуляция (ВТЭС)  1500 р.
# 3                Чрезкожная электростимуляция, 1 сеанс  1400 р.
# 4     Транскраниальная электростимуляция (1 процедура)   700 р.
# ..                                                 ...      ...
# 304                             Электростимуляция мышц   410 р.
# 305                               Электромиостимуляция   500 р.
# 306  Миоэлектростимуляция (электростимуляция аппара...   580 р.
# 307  Миоэлектростимуляция (электростимуляция аппара...   580 р.
# 308  Миоэлектростимуляция (электростимуляция аппара...   580 р.
#
# [309 rows x 3 columns]

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new[['Центр', 'Цена', 'Услуга']].to_excel('цены_' + file_excel, index=False)

# %%
data_new
# Out:
#                            Центр  \
# 0                    МЦ Династия
# 1           Клиника Доктора Пеля
# 2            Клиника Благодатная
# 3                          Дезир
# 4                      ДМЦ Гайде
# ..                           ...
# 303  Роддом №18 Санкт-Петербурга
# 304  ДГБ № 2 Св. Марии Магдалины
# 305  Роддом №13 Санкт-Петербурга
# 306      Детская поликлиника №35
# 308      Детская поликлиника №47
#
#                                                 Услуга  Цена
# 0                    Трансдермальная электростимуляция  1800
# 1         Транскраниальная электростимуляция (1 сеанс)   350
# 2             Внутритканевая электро-стимуляция (ВТЭС)  1500
# 3                Чрезкожная электростимуляция, 1 сеанс  1400
# 4     Транскраниальная электростимуляция (1 процедура)   700
# ..                                                 ...   ...
# 303           Транскраниальная электростимуляция (ТЭС)   400
# 304                             Электростимуляция мышц   410
# 305                               Электромиостимуляция   500
# 306  Миоэлектростимуляция (электростимуляция аппара...   580
# 308  Миоэлектростимуляция (электростимуляция аппара...   580
#
# [184 rows x 3 columns]
