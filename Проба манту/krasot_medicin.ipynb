# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование     цена
# 0                              РеаСанМед на Варшавской
# 2                                 Проба Манту (Россия)   920 р.
# 3                               МЦ Гайде на Херсонской
# 5    Постановка реакции Манту (включает осмотр врач...   950 р.
# 6                     ДМЦ Гайде на Лиговском проспекте
# ..                                                 ...      ...
# 331                                        Проба Манту  1400 р.
# 332                             СПГМУ им. И.П. Павлова
# 334                                 Проба Пирке, Манту   180 р.
# 335                 Противотуберкулезный диспансер №11
# 337  Внутрикожная проба с туберкулезным аллергеном ...   380 р.
#
# [236 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                                  Центр  \
# 0                              РеаСанМед на Варшавской
# 1                               МЦ Гайде на Херсонской
# 2                     ДМЦ Гайде на Лиговском проспекте
# 3                          СМТ на Московском проспекте
# 4                            СМТ на Римского-Корсакова
# ..                                                 ...
# 129  НИИ фтизиопульмонологии СПб на Лиговском просп...
# 130  НИИ фтизиопульмонологии СПб на Лиговском просп...
# 131         НИИ акушерства и гинекологии им. Д.О. Отта
# 132                             СПГМУ им. И.П. Павлова
# 133                 Противотуберкулезный диспансер №11
#
#                                                 Услуга     Цена
# 0                                 Проба Манту (Россия)   920 р.
# 1    Постановка реакции Манту (включает осмотр врач...   950 р.
# 2    Постановка реакции Манту (включает осмотр врач...   950 р.
# 3                               Постановка пробы Манту  1300 р.
# 4                               Постановка пробы Манту  1300 р.
# ..                                                 ...      ...
# 129   Реакция Манту с 2ТЕ (две туберкулиновые единицы)   500 р.
# 130               Учет результатов туберкулиновых проб   100 р.
# 131                                        Проба Манту  1400 р.
# 132                                 Проба Пирке, Манту   180 р.
# 133  Внутрикожная проба с туберкулезным аллергеном ...   380 р.
#
# [134 rows x 3 columns]

# %%
data_new['Центр'] = data_new['Центр'].apply(lambda x: x[:x.find(' на ')])
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
