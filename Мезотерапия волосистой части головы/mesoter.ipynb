# %%
import pandas as pd
import os

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'mesoter.ipynb',
#  '~$Мезотерапия волосистой части головы.xlsx',
#  'Мезотерапия волосистой части головы.xlsx']

# %%
data = pd.read_excel('Мезотерапия волосистой части головы.xlsx', sheet_name='Лист2')

data = data.fillna('')
data
# Out:
#                                         наименование      цена
# 0                            МЦ Династия на Репищева
# 1                        Микроэлементная мезотерапия   2900 р.
# 2                Многокомпонентная мезотерапия волос   3200 р.
# 3     Клиника Благодатная на проспекте Юрия Гагарина
# 4                Мезотерапия волосистой части головы   2600 р.
# ..                                               ...       ...
# 398          Лечение выпадения волос. Одна процедура   3500 р.
# 399  NCTF 135 (0, 025 ГК) (FILORGA) . Одна процедура   6000 р.
# 400                          Отражение на Пулковской
# 401   Filorga NCTF M-НА 10 Эмбриобласт (3 мл. 3 мл.)  14650 р.
# 402  Коктейль для укрепления и активации роста волос   3000 р.
#
# [403 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                                  Центр  \
# 0                              МЦ Династия на Репищева
# 1                              МЦ Династия на Репищева
# 2       Клиника Благодатная на проспекте Юрия Гагарина
# 3                МЦ Запад-Восток на Шкиперской протоке
# 4                    Своя клиника на Матроса Железняка
# ..                                                 ...
# 222  Международная академия здоровья на 4-й линии В.О.
# 223                                 Medall на Энгельса
# 224                                 Medall на Энгельса
# 225                            Отражение на Пулковской
# 226                            Отражение на Пулковской
#
#                                                 Услуга      Цена
# 0                          Микроэлементная мезотерапия   2900 р.
# 1                  Многокомпонентная мезотерапия волос   3200 р.
# 2                  Мезотерапия волосистой части головы   2600 р.
# 3    Мезотерапия волосистой части головы БЕЗ стоимо...   5500 р.
# 4     Мезотерапия для волос VICINO PEPTO Hair (2, 5ml)   2750 р.
# ..                                                 ...       ...
# 222                                  Мезотерапия волос   4650 р.
# 223            Лечение выпадения волос. Одна процедура   3500 р.
# 224    NCTF 135 (0, 025 ГК) (FILORGA) . Одна процедура   6000 р.
# 225     Filorga NCTF M-НА 10 Эмбриобласт (3 мл. 3 мл.)  14650 р.
# 226    Коктейль для укрепления и активации роста волос   3000 р.
#
# [227 rows x 3 columns]

# %%
data_new['Центр'] = data_new['Центр'].apply(lambda x: x[:x.find(' на ')])
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new.to_excel('цены.xlsx')
