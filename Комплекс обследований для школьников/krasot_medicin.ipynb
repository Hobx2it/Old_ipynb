# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование     цена
# 0                              МЦ Династия на Репищева
# 2    Оформление медицинской карты ребенка в школу (...  5000 р.
# 3                                    Медика на Бадаева
# 5    "Оформление справки в школу (форма № 026/у - 2...  9900 р.
# 6                      Семь Докторов на 10-й Советской
# ..                                                 ...      ...
# 101  Оформление медицинской карты для детского сада...  4800 р.
# 102                               Феникс мед в Колпино
# 104                   Справка по форме 026/у для школы  5300 р.
# 105                           Моя Клиника в Кингисеппе
# 107  Справка по форме 026/у-2000 для поступления в ...  5600 р.
#
# [72 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                         Центр  \
# 0                     МЦ Династия на Репищева
# 1                           Медика на Бадаева
# 2             Семь Докторов на 10-й Советской
# 3                       МЦ Династия на Ленина
# 4               Долголетие на Малой Посадской
# 5                    Долголетие на Бронницкой
# 6          Долголетие в Крестьянском переулке
# 7   МЦ Основа Дети На Комендантском проспекте
# 8                  МЦ Династия во Всеволожске
# 9            Аранна Меди на Краснопутиловской
# 10                 Абиа на проспекте Королёва
# 11            БалтМед на Васильевском Острове
# 12                БалтМед на Выборгском шоссе
# 13                   Квантум Сатис у Звёздной
# 14                        Мир семьи Юго-Запад
# 15              Таурас-Мед на Торфяной дороге
# 16                   Моя Клиника на Гороховой
# 17                           Мир семьи Парнас
# 18                     Элеос на Ланском шоссе
# 19                  Моя Клиника на Варшавской
# 20                   MedSwiss на Гаккелевской
# 21              Виталис на Морской набережной
# 22                           Мир семьи Шушары
# 23                   Квантум Сатис в Горелово
# 24                    Квантум Сатис в Купчино
# 25             Элеос на проспекте Большевиков
# 26            ЮниОрт на проспекте Просвещения
# 27                          ЮниОрт на Оптиков
# 28                        ЮниОрт на Савушкина
# 29           Rossimed на Российском проспекте
# 30                          Элеос на Гжатской
# 31      Клиника Здоровья Семьи на Декабристов
# 32   Элеос на 12-й линии Василевского Острова
# 33              Детский МЦ M+Clinic в Кудрово
# 34                       Феникс мед в Колпино
# 35                   Моя Клиника в Кингисеппе
#
#                                                Услуга      Цена
# 0   Оформление медицинской карты ребенка в школу (...   5000 р.
# 1   "Оформление справки в школу (форма № 026/у - 2...   9900 р.
# 2   Программа "В школу" (осмотры педиатра, невроло...  14795 р.
# 3   Оформление медицинской карты ребенка в школу (...   5000 р.
# 4                      Карта в школу 026/у ЭХО сердца   8900 р.
# 5                      Карта в школу 026/у ЭХО сердца   8900 р.
# 6                      Карта в школу 026/у ЭХО сердца   8900 р.
# 7   026/у-2000 (форма 026/у) медицинская карта реб...   9100 р.
# 8   Оформление медицинской карты ребенка в школу (...   5000 р.
# 9   Оформление медицинской карты 026/у старше 14 л...   8820 р.
# 10  : педиатр, невролог, хирург, офтальмолог, псих...   8400 р.
# 11  Услуги клиники Осмотр специалистов перед школо...  16000 р.
# 12  Услуги клиники Осмотр специалистов перед школо...  16000 р.
# 13  Медицинская карта 026у для школы, включая анализы  11650 р.
# 14  Оформление карты 026/у семейным врачом с анали...   4000 р.
# 15  Медицинская карта ребенка в общеобразовательно...  12500 р.
# 16  Справка по форме 026/у-2000 для поступления в ...   5600 р.
# 17  Оформление карты 026/у семейным врачом с анали...   4000 р.
# 18                Карта в школу для вновь поступающих   7000 р.
# 19  Справка по форме 026/у-2000 для поступления в ...   5600 р.
# 20  Оформление медицинской карты для поступления в...  11300 р.
# 21  «Подробный медосмотр к школе»: педиатр специал...  10400 р.
# 22  Оформление карты 026/у семейным врачом с анали...   4000 р.
# 23  Медицинская карта 026у для школы, включая анализы  11650 р.
# 24  Медицинская карта 026у для школы, включая анализы  11650 р.
# 25                Карта в школу для вновь поступающих   7000 р.
# 26  оформление мед. карт для школы с анализами/без...   5000 р.
# 27  оформление мед. карт для школы с анализами/без...   5000 р.
# 28  оформление мед. карт для школы с анализами/без...   5000 р.
# 29  Оформление медицинской карты ребенка (Ф 026/у-...  11190 р.
# 30                Карта в школу для вновь поступающих   7000 р.
# 31  Оформление карты для детского и школьного учре...   3900 р.
# 32                Карта в школу для вновь поступающих   7000 р.
# 33  Оформление медицинской карты для детского сада...   4800 р.
# 34                   Справка по форме 026/у для школы   5300 р.
# 35  Справка по форме 026/у-2000 для поступления в ...   5600 р.

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
