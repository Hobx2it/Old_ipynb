# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                        наименование     цена
# 0    Клиника Благодатная на проспекте Юрия Гагарина
# 2                                 Ректороманоскопия  1000 р.
# 3                           Скандинавия на Ильюшина
# 5                                 Ректороманоскопия  2000 р.
# 6                 СМ-Клиника на Дунайском проспекте
# ..                                              ...      ...
# 407                               Ректороманоскопия   970 р.
# 408               Городская больница № 33 в Колпино
# 410                               Ректороманоскопия  1200 р.
# 411  Городская больница №9 на Крестовском проспекте
# 413                         Ректороманоскопия (РРС)   900 р.
#
# [279 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                               Центр  \
# 0    Клиника Благодатная на проспекте Юрия Гагарина
# 1                           Скандинавия на Ильюшина
# 2                 СМ-Клиника на Дунайском проспекте
# 3                 СМ-Клиника на Дунайском проспекте
# 4                 СМ-Клиника на проспекте Ударников
# ..                                              ...
# 139                            МСЧ №70 на Комсомола
# 140                            МСЧ №70 на Комсомола
# 141              МСЧ ГУП Водоканал Санкт-Петербурга
# 142               Городская больница № 33 в Колпино
# 143  Городская больница №9 на Крестовском проспекте
#
#                                 Услуга     Цена
# 0                    Ректороманоскопия  1000 р.
# 1                    Ректороманоскопия  2000 р.
# 2    Ректороманоскопия диагностическая  1400 р.
# 3           Ректороманоскопия лечебная  1600 р.
# 4    Ректороманоскопия диагностическая  1400 р.
# ..                                 ...      ...
# 139                  Ректороманоскопия  1000 р.
# 140       Ректороманоскопия с биопсией  1400 р.
# 141                  Ректороманоскопия   970 р.
# 142                  Ректороманоскопия  1200 р.
# 143            Ректороманоскопия (РРС)   900 р.
#
# [144 rows x 3 columns]

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new[['Центр', 'Цена', 'Услуга']].to_excel('цены_' + file_excel, index=False)
