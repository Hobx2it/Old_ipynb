# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование      цена
# 0                               МЦ Гайде на Херсонской
# 2                           Удаление фиксатора (спицы)   3500 р.
# 3                     ДМЦ Гайде на Лиговском проспекте
# 5                           Удаление фиксатора (спицы)   3500 р.
# 6                          СМТ на Московском проспекте
# ..                                                 ...       ...
# 170                                     Удаление спицы   1500 р.
# 171  НИИ фтизиопульмонологии СПб на Лиговском просп...
# 173  Удаление инородного тела кости экстрамедуллярн...  15000 р.
# 174    ДГБ № 2 Св. Марии Магдалины на 2-ой линии В. О.
# 176  Удаление внутреннего фиксирующего устройства (...   3600 р.
#
# [118 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                                 Центр  \
# 0                              МЦ Гайде на Херсонской
# 1                    ДМЦ Гайде на Лиговском проспекте
# 2                         СМТ на Московском проспекте
# 3                           СМТ на Римского-Корсакова
# 4                            СМТ на Валерия Гаврилина
# 5                    TTLife на Лабораторном проспекте
# 6                              МСЧ №157 на Варшавской
# 7                     МЦ Март на Малом проспекте В.О.
# 8                            XXI век на Б. Пушкарской
# 9                        XXI век на Валерия Гаврилина
# 10                             Гранти-Мед на Чекистов
# 11                             Гранти-Мед на Корнеева
# 12            XXI век на Старо-Петергофском проспекте
# 13                       XXI век на проспекте Маршака
# 14                 XXI век на Комендантском проспекте
# 15                              Гранти-Мед на Рылеева
# 16                            Скандинавия на Ильюшина
# 17                          Согаз на Малой Конюшенной
# 18                    Адмиралтейские Верфи на Садовой
# 19                   Санкт-Петербургская больница РАН
# 20                   Американская медицинская клиника
# 21                           MedSwiss на Гаккелевской
# 22                                      ЕМС на Победы
# 23                         МЕДСИ на Академика Павлова
# 24                          Согаз на проспекте Стачек
# 25                                    Согаз в Колпино
# 26             XXI век на Б. Сампсониевском проспекте
# 27                   Rossimed на Российском проспекте
# 28                   XXI век на Коломяжском проспекте
# 29                 XXI век на Пограничника Гарькавого
# 30                             Гранти-Мед на Гаврской
# 31                                  XXI век на Марата
# 32                      XXI век на проспекте Косыгина
# 23    Удаление металлоконструкции 1 спица (над кожей)   3300 р.
# 24  Удаление металлоконструкций (винт, спица) под ...   2350 р.
# 25          Удаление металлоконструкций (винт, спица)   1500 р.
# 26  Удаление позиционного винта после остеосинтеза...  12900 р.
# 27  Операции по удалению металлоконструкций 1 кате...   3200 р.
# 28  Удаление позиционного винта после остеосинтеза...  12900 р.
# 29  Удаление позиционного винта после остеосинтеза...  12900 р.
# 30                             Удаление спицы (одной)   2200 р.
# 31  Удаление позиционного винта после остеосинтеза...  12900 р.
# 32  Удаление позиционного винта после остеосинтеза...  12900 р.
# 33  Удаление позиционного винта после остеосинтеза...  12900 р.
# 34  Удаление позиционного винта после остеосинтеза...  12900 р.
# 35  Удаление позиционного винта после остеосинтеза...  12900 р.
# 36  Удаление позиционного винта после остеосинтеза...  12900 р.
# 37  Удаление позиционного винта после остеосинтеза...  12900 р.
# 38                             Удаление спицы (одной)   2200 р.
# 39  Удаление позиционного винта после остеосинтеза...  12900 р.
# 40  Удаление позиционного винта после остеосинтеза...  12900 р.
# 41  Удаление позиционного винта после остеосинтеза...  12900 р.
# 42  Удаление позиционного винта после остеосинтеза...  12900 р.
# 43  Удаление инородного тела кости интрамедулярных...   1600 р.
# 44  Удаление инородного тела кости интрамедулярных...   1600 р.
# 45                 Удаление винтов и фиксирующих спиц   3000 р.
# 46                  Удаление малых металлоконструкций   1400 р.
# 47                  Удаление малых металлоконструкций   1400 р.
# 48       Удаление внутреннего фиксирующего устройства   9000 р.
# 49  Удаление внутренних фиксирующих устройств (1-3...    575 р.
# 50       Удаление чрезкожно введенных спиц и проволок   2000 р.
# 51  Удаление внутреннего фиксирующего устройства (...   1230 р.
# 52  3. Удаление металлоконструкций (без учета стои...   2490 р.
# 53         Удаление наружного фиксирующего устройства   5000 р.
# 54  Удаление импланта малого (в т. ч. спиц, провол...   4300 р.
# 55  Удаление инородного тела кости экстрамедуллярн...  15000 р.
# 56                                     Удаление спицы   1500 р.
# 57  Удаление инородного тела кости экстрамедуллярн...  15000 р.
# 58  Удаление внутреннего фиксирующего устройства (...   3600 р.

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new[['Центр', 'Цена', 'Услуга']].to_excel('цены_' + file_excel, index=False)
