# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                        наименование      цена
# 0    Клиника Благодатная на проспекте Юрия Гагарина
# 2                                     Белотеро Софт  16000 р.
# 3                                   Белотеро Volume  17000 р.
# 4                                  Белотеро Intense  13000 р.
# 5                                   Белотеро баланс  13000 р.
# ..                                              ...       ...
# 935                                   Neuramis Deep  13000 р.
# 936                             Ювенис на Плуталова
# 938                            Neuramis Deep (1, 0)  11900 р.
# 939              Энигма на Кондратьевском проспекте
# 941                     Neuramis Deep (Южная Корея)  10200 р.
#
# [734 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                               Центр  \
# 0    Клиника Благодатная на проспекте Юрия Гагарина
# 1    Клиника Благодатная на проспекте Юрия Гагарина
# 2    Клиника Благодатная на проспекте Юрия Гагарина
# 3    Клиника Благодатная на проспекте Юрия Гагарина
# 4                        GMTClinic на Льва Толстого
# ..                                              ...
# 518                Melissa на проспекте Космонавтов
# 519                        CapitalMed на Полтавской
# 520                     NuAnce на Профессора Попова
# 521                             Ювенис на Плуталова
# 522              Энигма на Кондратьевском проспекте
#
#                                         Услуга      Цена
# 0                                Белотеро Софт  16000 р.
# 1                              Белотеро Volume  17000 р.
# 2                             Белотеро Intense  13000 р.
# 3                              Белотеро баланс  13000 р.
# 4                                Belotero Soft  16200 р.
# ..                                         ...       ...
# 518  Neuramis Deep (Нейрамис Дип с лидокаином)   8000 р.
# 519                        Neuramis Deep, 1 ml  14500 р.
# 520                              Neuramis Deep  13000 р.
# 521                       Neuramis Deep (1, 0)  11900 р.
# 522                Neuramis Deep (Южная Корея)  10200 р.
#
# [523 rows x 3 columns]

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
