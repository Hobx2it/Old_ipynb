# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'])

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                          наименование     цена
# 0                             МЦ Династия на Репищева
# 2               Первичная консультация нейрофизиолога  1200 р.
# 3                               МЦ Династия на Ленина
# 5               Первичная консультация нейрофизиолога  1200 р.
# 6               Деликатная терапия души на Жуковского
# 8               Первичная консультация нейрофизиолога  1200 р.
# 9                          МЦ Династия во Всеволожске
# 11              Первичная консультация нейрофизиолога  1200 р.
# 12              МЦ Светофор на проспекте Луначарского
# 14  Консультативный приём врача высшей категории, ...  1600 р.
# 15                Деликатная терапия души на Репищева
# 17              Первичная консультация нейрофизиолога  1200 р.

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                    Центр  \
# 0                МЦ Династия на Репищева
# 1                  МЦ Династия на Ленина
# 2  Деликатная терапия души на Жуковского
# 3             МЦ Династия во Всеволожске
# 4  МЦ Светофор на проспекте Луначарского
# 5    Деликатная терапия души на Репищева
#
#                                               Услуга     Цена
# 0              Первичная консультация нейрофизиолога  1200 р.
# 1              Первичная консультация нейрофизиолога  1200 р.
# 2              Первичная консультация нейрофизиолога  1200 р.
# 3              Первичная консультация нейрофизиолога  1200 р.
# 4  Консультативный приём врача высшей категории, ...  1600 р.
# 5              Первичная консультация нейрофизиолога  1200 р.

# %%
data_new['Центр'] = data_new['Центр'].apply(lambda x: x[:x.find(' на ')])
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
