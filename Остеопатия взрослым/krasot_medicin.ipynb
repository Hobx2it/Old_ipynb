# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2')

data = data.fillna('')
data
# Out:
#                                          наименование     цена
# 0                             МЦ Династия на Репищева
# 1                       Сеанс остеопатии для взрослых  3000 р.
# 2                          Сеанс остеопатии для детей  2700 р.
# 3                             РеаСанМед на Варшавской
# 4                                    Сеанс остеопатии  4500 р.
# ..                                                ...      ...
# 86                                Мир семьи Юго-Запад
# 87   Сеанс мануальной терапии с элементами остеопатии  3500 р.
# 88    Сеанс остеопатической коррекции ребенка, 45 мин  3200 р.
# 89                     Тентанда Виа на Межевом Канале
# 90  Сеанс мануальной терапии/массаж/остеопатически...  3600 р.
#
# [91 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                                Центр  \
# 0                            МЦ Династия на Репищева
# 1                            МЦ Династия на Репищева
# 2                            РеаСанМед на Варшавской
# 3             Энергия Здоровья на проспекте Энгельса
# 4                    МЦ Март на Малом проспекте В.О.
# 5                      Таурас-Мед на Торфяной дороге
# 6                        Поэма Здоровья на Астафьева
# 7              ЕвроМедика на Комендантском проспекте
# 8                      Долголетие на Малой Посадской
# 9                        БалтМед на Выборгском шоссе
# 10                          Долголетие на Бронницкой
# 11                Euromed Kids на проспекте Энгельса
# 12                Euromed Kids на проспекте Энгельса
# 13                       Аванта на Невском проспекте
# 14                                 Медика на Бадаева
# 15                                 Медика на Бадаева
# 16                             МЦ Династия на Ленина
# 17                             МЦ Династия на Ленина
# 18                              Флеболайф на Блохина
# 19           Центр медицины плода на 14-й линии В.О.
# 20           Центр медицины плода на 14-й линии В.О.
# 21                Долголетие в Крестьянском переулке
# 22                        Euromed Kids на Варшавской
# 23                        Euromed Kids на Варшавской
# 24                            МЦ Лекарь на Корпусной
# 25                            МЦ Лекарь на Корпусной
# 26                 Клиника Громовой С.Б. на Кирочной
# 27  Европейский остеопатический центр на Поликарпова
# 28                       Поэма Здоровья на Ленсовета
# 29                        МЦ Династия во Всеволожске
# 30                        МЦ Династия во Всеволожске
# 31        Центр травматологии и ортопедии на Руднева
# 32                            Мэдис на 5-й Советской
# 33                                  ЦМРТ на Типанова
# 34         Клиника Позвоночника доктора Разумовского
# 35                                Аврора на Крыленко
# 36                                Аврора на Крыленко
# 37                МЦ Доктор на проспекте Энтузиастов
# 38                            Рута на Фермском шоссе
# 39    Центр Клинической Неврологии и ЦМРТ на Ленской
# 40                   БалтМед на Васильевском Острове
# 41                     Семейный Доктор на Парашютной
# 42                          Мэдис на Петропавловской
# 43                                  ЦМРТ на Типанова
# 44           Longa Vita на Большеохтинском проспекте
# 45           Longa Vita на Большеохтинском проспекте
# 46                    ЦМРТ Петроградский на Рентгена
# 47                                Диона на Коллонтай
# 48                               Мир семьи Юго-Запад
# 49                               Мир семьи Юго-Запад
# 50                    Тентанда Виа на Межевом Канале
#
#                                                Услуга     Цена
# 0                       Сеанс остеопатии для взрослых  3000 р.
# 1                          Сеанс остеопатии для детей  2700 р.
# 2                                    Сеанс остеопатии  4500 р.
# 3                                Остеопатия (1 сеанс)  3200 р.
# 4       Сеанс мануальной терапии и остеопатии, 45 мин  3100 р.
# 5                    Сеанс остеопатический (60 минут)  3000 р.
# 6                          Сеанс остеопатии для детей  1760 р.
# 7                                    Сеанс остеопатии  2950 р.
# 8                Сеанс остеопатии (Котелевский А. В.)  3500 р.
# 9                 Услуги клиники Остеопатия (1 сеанс)  4000 р.
# 10               Сеанс остеопатии (Котелевский А. В.)  3500 р.
# 11  Сеанс остеопатического лечения (с консультацие...  5000 р.
# 12  Сеанс остеопатического лечения ребенка (с конс...  4000 р.
# 13          Сеанс остеопатии продолжительность 45 мин  3000 р.
# 14  Сеанс лечения врача-остеопата (взрослые и дети...  4200 р.
# 15     Сеанс лечения врача-остеопата (дети до 12 лет)  3800 р.
# 16                      Сеанс остеопатии для взрослых  3000 р.
# 17                         Сеанс остеопатии для детей  2700 р.
# 18  Лечебный медицинский массаж с остеопатической ...  4500 р.
# 19  Сеанс лечения врача-остеопата (взрослые и дети...  4000 р.
# 20     Сеанс лечения врача-остеопата (дети до 12 лет)  3500 р.
# 21               Сеанс остеопатии (Котелевский А. В.)  3500 р.
# 22  Сеанс остеопатического лечения (с консультацие...  5000 р.
# 23  Сеанс остеопатического лечения ребенка (с конс...  4000 р.
# 24                 Лечение остеопатическое (взрослые)  4000 р.
# 25                     Лечение остеопатическое (дети)  3500 р.
# 26                                         Остеопатия  3500 р.
# 27                        Процедура у врача остеопата  4500 р.
# 28                         Сеанс остеопатии для детей  1760 р.
# 29                      Сеанс остеопатии для взрослых  3000 р.
# 30                         Сеанс остеопатии для детей  2700 р.
# 31                                   Сеанс остеопатии  4000 р.
# 32                  Остеопатическое лечение (1 сеанс)  3200 р.
# 33                                         Остеопатия  3500 р.
# 34                                         Остеопатия  3200 р.
# 35                   Первичный прием сеанс остеопатии  4000 р.
# 36         Лечебный сеанс остеопатии (дети до 10 лет)  2500 р.
# 37  Сеанс комплексной мануальной терапии с элемент...  2400 р.
# 38  Остеопатия (мягкие техники мануальной терапии ...  3000 р.
# 39       Мануальная терапия/остеопатическая коррекция  3500 р.
# 40                Услуги клиники Остеопатия (1 сеанс)  4000 р.
# 41                              Остеопатический сеанс  3500 р.
# 42                  Остеопатическое лечение (1 сеанс)  3200 р.
# 43                                         Остеопатия  3500 р.
# 44           Сеанс остеопатического лечения взрослого  3200 р.
# 45  Сеанс остеопатического лечения ребенка (до 15 ...  2700 р.
# 46                                         Остеопатия  3500 р.
# 47                                   Сеанс остеопатии  2500 р.
# 48   Сеанс мануальной терапии с элементами остеопатии  3500 р.
# 49    Сеанс остеопатической коррекции ребенка, 45 мин  3200 р.
# 50  Сеанс мануальной терапии/массаж/остеопатически...  3600 р.

# %%
data_new['Центр'] = data_new['Центр'].apply(lambda x: x[:x.find(' на ')])
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены.xlsx', index=False)
