# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование     цена
# 0                          БалтМед на Выборгском шоссе
# 2    Услуги клиники Тимпанометрия (акустическая имп...   800 р.
# 3                          СМТ на Московском проспекте
# 5    Компьютерная тимпанометрия с регистрацией акус...   740 р.
# 6                            СМТ на Римского-Корсакова
# ..                                                 ...      ...
# 143                                    Импедансометрия   600 р.
# 144            Дорожная клиническая больница ОАО «РЖД»
# 146                                    Импедансометрия  1060 р.
# 147          НИИ детских инфекций на Профессора Попова
# 149                                    Импедансометрия   500 р.
#
# [100 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                          Центр  \
# 0                  БалтМед на Выборгском шоссе
# 1                  СМТ на Московском проспекте
# 2                    СМТ на Римского-Корсакова
# 3                     СМТ на Валерия Гаврилина
# 4             Аранна Меди на Краснопутиловской
# 5                       МСЧ №157 на Варшавской
# 6                     Моя Клиника на Гороховой
# 7              БалтМед на Васильевском Острове
# 8                     XXI век на Б. Пушкарской
# 9                    Моя Клиника на Варшавской
# 10                XXI век на Валерия Гаврилина
# 11     XXI век на Старо-Петергофском проспекте
# 12          XXI век на Комендантском проспекте
# 13                XXI век на проспекте Маршака
# 14                   Меди на Невском проспекте
# 15          Меди на на Комендантском проспекте
# 16                     ФГБУ КДЦ с поликлиникой
# 17                     Скандинавия на Ильюшина
# 18                    MedSwiss на Гаккелевской
# 19                            РАМИ на Кирочной
# 20              Вирилис на Ленинском проспекте
# 21                Клиника имени Петра Великого
# 22                     Скандинавия на Парадной
# 23      XXI век на Б. Сампсониевском проспекте
# 24            XXI век на Коломяжском проспекте
# 25          XXI век на Пограничника Гарькавого
# 26                           XXI век на Марата
# 27               XXI век на проспекте Косыгина
# 28                 Ю-Мед на Большой Московской
# 29                        XXI век на Щербакова
# 30  Центр профпатологии на проспекте Мечникова
# 31                XXI век в Моравском переулке
# 32                        XXI век на Сикейроса
# 33                         XXI век на Гастелло
# 34                   XXI век на проспекте КИМа
# 35        Snoring Clinic на Литейном проспекте
# 36              Мелфон на Московском проспекте
# 37                         XXI век на Брянцева
# 38                      XXI век на Коллонтай 4
# 39                      XXI век на Коллонтай 6
# 40            XXI век на Богатырском проспекте
# 41                         Ю-Мед на Бронницкой
# 42                    Моя Клиника в Кингисеппе
# 43  Военно-медицинская академия им. С.М.Кирова
# 44                   СПб НИИ ЛОР на Бронницкой
# 45                      СПГМУ им. И.П. Павлова
# 46                            Клиника СПб ГПМУ
# 47                   КБ №122 им. Л.Г. Соколова
# 48     Дорожная клиническая больница ОАО «РЖД»
# 49   НИИ детских инфекций на Профессора Попова
#
#                                                Услуга     Цена
# 0   Услуги клиники Тимпанометрия (акустическая имп...   800 р.
# 1   Компьютерная тимпанометрия с регистрацией акус...   740 р.
# 2   Компьютерная тимпанометрия с регистрацией акус...   740 р.
# 3   Компьютерная тимпанометрия с регистрацией акус...   740 р.
# 4          Акустическая импедансометрия в амбулатории   984 р.
# 5                                     Импедансометрия   600 р.
# 6                                     Импедансометрия  1000 р.
# 7   Услуги клиники Тимпанометрия (акустическая имп...   800 р.
# 8          Акустическая импедансометрия в амбулатории   950 р.
# 9                                     Импедансометрия  1000 р.
# 10         Акустическая импедансометрия в амбулатории   950 р.
# 11         Акустическая импедансометрия в амбулатории   950 р.
# 12         Акустическая импедансометрия в амбулатории   950 р.
# 13         Акустическая импедансометрия в амбулатории   950 р.
# 14                                    Импедансометрия  1230 р.
# 15                                    Импедансометрия   744 р.
# 16                                    Импедансометрия   500 р.
# 17                                    Импедансометрия  2100 р.
# 18                                    Импедансометрия  1050 р.
# 19  Компьютерная импедансометрия с регистрацией ак...  5200 р.
# 20  Исследование на Импедансометре (импедансометри...  1200 р.
# 21                       Акустическая импедансометрия   330 р.
# 22                                    Импедансометрия  2800 р.
# 23         Акустическая импедансометрия в амбулатории   950 р.
# 24         Акустическая импедансометрия в амбулатории   950 р.
# 25         Акустическая импедансометрия в амбулатории   950 р.
# 26         Акустическая импедансометрия в амбулатории   950 р.
# 27         Акустическая импедансометрия в амбулатории   950 р.
# 28                                    Импедансометрия   600 р.
# 29         Акустическая импедансометрия в амбулатории   950 р.
# 30                                    Импедансометрия   150 р.
# 31         Акустическая импедансометрия в амбулатории   950 р.
# 32         Акустическая импедансометрия в амбулатории   950 р.
# 33         Акустическая импедансометрия в амбулатории   950 р.
# 34         Акустическая импедансометрия в амбулатории   950 р.
# 35                       Акустическая импедансометрия  1000 р.
# 36  Импедансометрия (тимпанометрия и акустическая ...  1700 р.
# 37         Акустическая импедансометрия в амбулатории   950 р.
# 38         Акустическая импедансометрия в амбулатории   950 р.
# 39         Акустическая импедансометрия в амбулатории   950 р.
# 40         Акустическая импедансометрия в амбулатории   950 р.
# 41                                    Импедансометрия   600 р.
# 42                                    Импедансометрия  1000 р.
# 43                                    Импедансометрия  1500 р.
# 44                                    Импедансометрия   850 р.
# 45                       Компьютерная импедансометрия   900 р.
# 46                       Компьютерная импедансометрия   500 р.
# 47                                    Импедансометрия   600 р.
# 48                                    Импедансометрия  1060 р.
# 49                                    Импедансометрия   500 р.

# %%
data_new['Центр'] = data_new['Центр'].apply(lambda x: x[:x.find(' на ')])
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
