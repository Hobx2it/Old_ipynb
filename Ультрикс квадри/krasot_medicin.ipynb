# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование     цена
# 0                              Скандинавия на Ильюшина
# 2    Иммунопрофилактика от гриппа (вакцина Инфлювак...  1300 р.
# 3    Иммунопрофилактика от гриппа (вакцина Инфлювак...  1300 р.
# 4    Иммунопрофилактика от гриппа (вакцина Инфлювак...  1300 р.
# 5    Иммунопрофилактика от гриппа (вакцина Инфлювак...  1300 р.
# ..                                                 ...      ...
# 173                            Вакцинация Гриппол плюс   500 р.
# 174                              Вакцинация Ваксигрипп   570 р.
# 175                                показать еще 2 цены
# 176                      МЦ Ева в Гатчине на Рощинской
# 178                     «Ультрикс» (вакцина от гриппа)   800 р.
#
# [136 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                             Центр  \
# 0         Скандинавия на Ильюшина
# 1         Скандинавия на Ильюшина
# 2         Скандинавия на Ильюшина
# 3         Скандинавия на Ильюшина
# 4         Скандинавия на Ильюшина
# ..                            ...
# 66           Феникс мед в Колпино
# 67           Феникс мед в Колпино
# 68       Моя Клиника в Кингисеппе
# 69       Моя Клиника в Кингисеппе
# 70  МЦ Ева в Гатчине на Рощинской
#
#                                                Услуга     Цена
# 0   Иммунопрофилактика от гриппа (вакцина Инфлювак...  1300 р.
# 1   Иммунопрофилактика от гриппа (вакцина Инфлювак...  1300 р.
# 2   Иммунопрофилактика от гриппа (вакцина Инфлювак...  1300 р.
# 3   Иммунопрофилактика от гриппа (вакцина Инфлювак...  1300 р.
# 4   Иммунопрофилактика от гриппа (вакцина Инфлювак...  1300 р.
# ..                                                ...      ...
# 66  Вакцинация от гриппа вакциной Гриппол® плюс и ...   700 р.
# 67             Вакцинация от гриппа вакциной Ультрикс   900 р.
# 68                            Вакцинация Гриппол плюс   500 р.
# 69                              Вакцинация Ваксигрипп   570 р.
# 70                     «Ультрикс» (вакцина от гриппа)   800 р.
#
# [71 rows x 3 columns]

# %%
data_new['Центр'] = data_new['Центр'].apply(lambda x: x[:x.find(' на ')])
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
