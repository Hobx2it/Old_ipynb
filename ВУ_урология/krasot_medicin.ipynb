# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                            наименование     цена
# 0                              CapitalMed на Полтавской
# 2                        Первичная консультация уролога  2000 р.
# 3                        Повторная консультация уролога  1500 р.
# 4                        Повторная консультация уролога  1500 р.
# 5                               МЦ Династия на Репищева
# ...                                                 ...      ...
# 2892  Прием (осмотр, консультация) врача - уролога а...   800 р.
# 2893                Детская поликлиника №47 на Костюшко
# 2895  Профилактический прием (осмотр, консультация) ...   700 р.
# 2896  Прием (осмотр, консультация) врача -уролога ан...  1000 р.
# 2897  Прием (осмотр, консультация) врача - уролога а...   800 р.
#
# [2382 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                            Центр  \
# 0                       CapitalMed на Полтавской
# 1                       CapitalMed на Полтавской
# 2                       CapitalMed на Полтавской
# 3                        МЦ Династия на Репищева
# 4                        МЦ Династия на Репищева
# ...                                          ...
# 1861  Детская поликлиника №35 в Детском переулке
# 1862  Детская поликлиника №35 в Детском переулке
# 1863         Детская поликлиника №47 на Костюшко
# 1864         Детская поликлиника №47 на Костюшко
# 1865         Детская поликлиника №47 на Костюшко
#
#                                                  Услуга     Цена
# 0                        Первичная консультация уролога  2000 р.
# 1                        Повторная консультация уролога  1500 р.
# 2                        Повторная консультация уролога  1500 р.
# 3        Первичный прием (осмотр, консультация) уролога  1650 р.
# 4     Первичный прием (осмотр, консультация) уролога...  2200 р.
# ...                                                 ...      ...
# 1861  Прием (осмотр, консультация) врача -уролога ан...  1000 р.
# 1862  Прием (осмотр, консультация) врача - уролога а...   800 р.
# 1863  Профилактический прием (осмотр, консультация) ...   700 р.
# 1864  Прием (осмотр, консультация) врача -уролога ан...  1000 р.
# 1865  Прием (осмотр, консультация) врача - уролога а...   800 р.
#
# [1866 rows x 3 columns]

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new[['Центр', 'Цена', 'Услуга']].to_excel('цены_' + file_excel, index=False)
