# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование     цена
# 0                 Аква-Доктор на Богатырском проспекте
# 2    Вакцинация против гепатита А вакциной «Альгава...  3075 р.
# 3    Вакцинация против гепатита А вакциной «Альгава...  2710 р.
# 4                              Скандинавия на Ильюшина
# 6    Иммунопрофилактика взрослых от вирусного гепат...  3100 р.
# ..                                                 ...      ...
# 95                   Вакцинация Гепатит А (Альгавак М)  2000 р.
# 96           Вакцинация Гепатит А (Альгавак М) детский  1800 р.
# 97                             ФГБУ КДЦ с поликлиникой
# 99   Вакцинация против вирусного гепатита А для взр...  1540 р.
# 100  Вакцинация против вирусного гепатита А для дет...  1340 р.
#
# [73 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                         Центр  \
# 0        Аква-Доктор на Богатырском проспекте
# 1        Аква-Доктор на Богатырском проспекте
# 2                     Скандинавия на Ильюшина
# 3                     Скандинавия на Ильюшина
# 4                     РеаСанМед на Варшавской
# 5                     РеаСанМед на Варшавской
# 6               Виталис на Морской набережной
# 7               Виталис на Морской набережной
# 8                 СМТ на Московском проспекте
# 9                   СМТ на Римского-Корсакова
# 10             Вирилис на Ленинском проспекте
# 11             Вирилис на Ленинском проспекте
# 12                    Скандинавия на Парадной
# 13                    Скандинавия на Парадной
# 14                    Скандинавия на Ильюшина
# 15                    Скандинавия на Ильюшина
# 16                   СМТ на Валерия Гаврилина
# 17                СМТ на Московском проспекте
# 18                  СМТ на Римского-Корсакова
# 19              Виталис на Морской набережной
# 20              Виталис на Морской набережной
# 21             Вирилис на Ленинском проспекте
# 22             Вирилис на Ленинском проспекте
# 23                    Скандинавия на Парадной
# 24                    Скандинавия на Парадной
# 25                   Квантум Сатис в Горелово
# 26                   Квантум Сатис у Звёздной
# 27        Мой доктор на проспекте Просвещения
# 28        Мой доктор на проспекте Просвещения
# 29                   Квантум Сатис в Горелово
# 30                   Квантум Сатис у Звёздной
# 31                   СМТ на Валерия Гаврилина
# 32                    Квантум Сатис в Купчино
# 33        Мой доктор на проспекте Просвещения
# 34        Мой доктор на проспекте Просвещения
# 35               Мой доктор в Новом Девяткино
# 36               Мой доктор в Новом Девяткино
# 37  НИИ детских инфекций на Профессора Попова
# 38  НИИ детских инфекций на Профессора Попова
# 39                    ФГБУ КДЦ с поликлиникой
# 40                    ФГБУ КДЦ с поликлиникой
# 41  НИИ детских инфекций на Профессора Попова
# 42  НИИ детских инфекций на Профессора Попова
# 43                    ФГБУ КДЦ с поликлиникой
# 44                    ФГБУ КДЦ с поликлиникой
#
#                                                Услуга     Цена
# 0   Вакцинация против гепатита А вакциной «Альгава...  3075 р.
# 1   Вакцинация против гепатита А вакциной «Альгава...  2710 р.
# 2   Иммунопрофилактика взрослых от вирусного гепат...  3100 р.
# 3   Иммунопрофилактика детей от вирусного гепатита...  2400 р.
# 4                                 Альгавак (взрослый)  1400 р.
# 5                                  Альгавак (детский)  1050 р.
# 6   Вакцинация против гепатита А вакциной «Альгава...  2975 р.
# 7   Вакцинация против гепатита А вакциной «Альгава...  2610 р.
# 8   Вакцинация против вирусного гепатита А (вакцин...  2310 р.
# 9   Вакцинация против вирусного гепатита А (вакцин...  2310 р.
# 10  Вакцинация против гепатита А вакциной «Альгава...  3075 р.
# 11  Вакцинация против гепатита А вакциной «Альгава...  2710 р.
# 12  Иммунопрофилактика взрослых от вирусного гепат...  3100 р.
# 13  Иммунопрофилактика детей от вирусного гепатита...  2400 р.
# 14  Иммунопрофилактика взрослых от вирусного гепат...  3100 р.
# 15  Иммунопрофилактика детей от вирусного гепатита...  2400 р.
# 16  Вакцинация против вирусного гепатита А (вакцин...  2310 р.
# 17  Вакцинация против вирусного гепатита А (вакцин...  2310 р.
# 18  Вакцинация против вирусного гепатита А (вакцин...  2310 р.
# 19  Вакцинация против гепатита А вакциной «Альгава...  2975 р.
# 20  Вакцинация против гепатита А вакциной «Альгава...  2610 р.
# 21  Вакцинация против гепатита А вакциной «Альгава...  3075 р.
# 22  Вакцинация против гепатита А вакциной «Альгава...  2710 р.
# 23  Иммунопрофилактика взрослых от вирусного гепат...  3100 р.
# 24  Иммунопрофилактика детей от вирусного гепатита...  2400 р.
# 25  Вакцинация взрослых против гепатита А. Альгава...  1700 р.
# 26  Вакцинация взрослых против гепатита А. Альгава...  1700 р.
# 27                              Альгавак М (взрослая)  2000 р.
# 28                     Альгавак М (детская с 3-х лет)  1700 р.
# 29  Вакцинация взрослых против гепатита А. Альгава...  1700 р.
# 30  Вакцинация взрослых против гепатита А. Альгава...  1700 р.
# 31  Вакцинация против вирусного гепатита А (вакцин...  2310 р.
# 32  Вакцинация взрослых против гепатита А. Альгава...  1700 р.
# 33                              Альгавак М (взрослая)  2000 р.
# 34                     Альгавак М (детская с 3-х лет)  1700 р.
# 35                              Альгавак М (взрослая)  2000 р.
# 36                     Альгавак М (детская с 3-х лет)  1700 р.
# 37                  Вакцинация Гепатит А (Альгавак М)  2000 р.
# 38          Вакцинация Гепатит А (Альгавак М) детский  1800 р.
# 39  Вакцинация против вирусного гепатита А для взр...  1540 р.
# 40  Вакцинация против вирусного гепатита А для дет...  1340 р.
# 41                  Вакцинация Гепатит А (Альгавак М)  2000 р.
# 42          Вакцинация Гепатит А (Альгавак М) детский  1800 р.
# 43  Вакцинация против вирусного гепатита А для взр...  1540 р.
# 44  Вакцинация против вирусного гепатита А для дет...  1340 р.

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new[['Центр', 'Цена', 'Услуга']].to_excel('цены_' + file_excel, index=False)
