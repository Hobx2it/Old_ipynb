# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                       наименование     цена
# 0                      СМТ на Московском проспекте
# 2                                     Биопсия кожи  2500 р.
# 3                        СМТ на Римского-Корсакова
# 5                                     Биопсия кожи  2500 р.
# 6           Энергия Здоровья на проспекте Энгельса
# ..                                             ...      ...
# 89                                    Биопсия кожи  1500 р.
# 90                                     ФГБУ РНЦРХТ
# 92                                    Биопсия кожи  2500 р.
# 93  Городская больница Святого Георгия на Северном
# 95                                    Биопсия кожи  1500 р.
#
# [64 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                                 Центр  \
# 0                         СМТ на Московском проспекте
# 1                           СМТ на Римского-Корсакова
# 2              Энергия Здоровья на проспекте Энгельса
# 3                   СМ-Клиника на Дунайском проспекте
# 4                   СМ-Клиника на проспекте Ударников
# 5                      СМ-Клиника на Маршала Захарова
# 6                       Медикус на проспекте Королёва
# 7                      СМ-Клиника на Выборгском шоссе
# 8                            СМТ на Валерия Гаврилина
# 9                    TTLife на Лабораторном проспекте
# 10                   Аранна Меди на Краснопутиловской
# 11                           Моя Клиника на Гороховой
# 12                          Моя Клиника на Варшавской
# 13                             АнИрМед на Бородинской
# 14               Медикус на проспекте Маршала Блюхера
# 15                                 М+Clinic в Кудрово
# 16                            Скандинавия на Ильюшина
# 17                       Клиника имени Петра Великого
# 18                   Американская медицинская клиника
# 19                            Скандинавия на Парадной
# 20          Медиус во Всеволожске на Социалистической
# 21         Медиус Южный во Всеволожске на Центральной
# 22                           Моя Клиника в Кингисеппе
# 23         Военно-медицинская академия им. С.М.Кирова
# 24                             СПГМУ им. И.П. Павлова
# 25            Дорожная клиническая больница ОАО «РЖД»
# 26                         НИИ СП им. И.И. Джанелидзе
# 27  ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Ак. Лебедева
# 28       ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Оптиков
# 29                         ГКБ №31 в Санкт-Петербурге
# 30                                        ФГБУ РНЦРХТ
# 31     Городская больница Святого Георгия на Северном
#
#                                                Услуга     Цена
# 0                                        Биопсия кожи  2500 р.
# 1                                        Биопсия кожи  2500 р.
# 2                         Забор биопсийного материала   700 р.
# 3           Биопсия кожи и слизистой I кат. сложности  2050 р.
# 4           Биопсия кожи и слизистой I кат. сложности  2050 р.
# 5           Биопсия кожи и слизистой I кат. сложности  2050 р.
# 6                                        Биопсия кожи  4000 р.
# 7           Биопсия кожи и слизистой I кат. сложности  2050 р.
# 8                                        Биопсия кожи  2500 р.
# 9                                        Биопсия кожи  2400 р.
# 10   Биопсия кожи (без гистологического исследования)   600 р.
# 11                    Биопсия кожи (за один препарат)  1300 р.
# 12                    Биопсия кожи (за один препарат)  1300 р.
# 13                 Биопсия кожи I категории сложности  4000 р.
# 14                                       Биопсия кожи  4000 р.
# 15                                       Биопсия кожи  2000 р.
# 16  Биопсия кожи (без стоимости гистологического и...  2200 р.
# 17                                       Биопсия кожи  1250 р.
# 18  Забор материала кожных покровов для гистологич...  4950 р.
# 19  Пункционная биопсия одного образования (без ст...  3000 р.
# 20                  Биопсия кожи (родинки за единицу)  1200 р.
# 21                  Биопсия кожи (родинки за единицу)  1200 р.
# 22                    Биопсия кожи (за один препарат)  1300 р.
# 23                                       Биопсия кожи  2500 р.
# 24  Биопсия кожи УЗИ-контроль и гистология оплачив...  1000 р.
# 25                                       Биопсия кожи  3300 р.
# 26                                       Биопсия кожи  5000 р.
# 27                                       Биопсия кожи  2000 р.
# 28                                       Биопсия кожи  2000 р.
# 29                                       Биопсия кожи  1500 р.
# 30                                       Биопсия кожи  2500 р.
# 31                                       Биопсия кожи  1500 р.

# %%
data_new['Центр'] = data_new['Центр'].apply(lambda x: x[:x.find(' на ')])
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
