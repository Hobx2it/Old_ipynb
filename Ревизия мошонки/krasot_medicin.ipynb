# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                          наименование      цена
# 0           Евромед Ин Витро на Суворовском проспекте
# 2   Ревизия органов мошонки/биопсия яичка/придатка...  24500 р.
# 3                    Евромед на Суворовском проспекте
# 5   Ревизия органов мошонки/биопсия яичка/придатка...  24500 р.
# 6                         СМТ на Московском проспекте
# 8                  Ревизия органов мошонки при травме   9200 р.
# 9                           СМТ на Римского-Корсакова
# 11                 Ревизия органов мошонки при травме   9200 р.
# 12                           СМТ на Валерия Гаврилина
# 14                 Ревизия органов мошонки при травме   9200 р.
# 15                   Американская медицинская клиника
# 17                            Ревизия органов мошонки  17600 р.
# 18                          Согаз на Малой Конюшенной
# 20                            Ревизия органов мошонки  14420 р.
# 21                                   РАМИ на Кирочной
# 23                 Ревизия органов мошонки при травме  26300 р.
# 24      Европейский Институт Здоровья Семьи на Ленина
# 26                                    Ревизия мошонки  15000 р.
# 27      Европейский Институт Здоровья Семьи в Колпино
# 29                                    Ревизия мошонки  15000 р.
# 30                                     АМДЦ на Орбели
# 32                    Ревизия мошонки с одной стороны  12000 р.
# 33                      Двухсторонняя ревизия мошонки  14000 р.
# 34  ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Ак. Лебедева
# 36            Ревизия органов мошонки (односторонняя)  10100 р.
# 37       ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Оптиков
# 39            Ревизия органов мошонки (односторонняя)  10100 р.
# 40                Клиническая больница Святителя Луки
# 42                        Ревизия мошонки при травмах  41950 р.
# 43  Александровская больница на проспекте Солидарн...
# 45                                    Ревизия мошонки  22400 р.
# 46     НИИ фтизиопульмонологии СПб на Политехнической
# 48                                    Ревизия мошонки   5500 р.
# 49            Дорожная клиническая больница ОАО «РЖД»
# 51                                    Ревизия мошонки   7500 р.
# 52       Ленинградская областная клиническая больница
# 54                                    Ревизия мошонки  11100 р.
# 55  НИИ фтизиопульмонологии СПб на Лиговском просп...
# 57                                    Ревизия мошонки   5500 р.
# 58               МСЧ МВД России на проспекте Культуры
# 60                                    Ревизия мошонки   5000 р.
# 61              ЛДЦ МИБС им. С.М. Березина в Песочном
# 63                            Ревизия органов мошонки  20000 р.
# 64                               МСЧ №70 на Комсомола
# 66                                    Ревизия мошонки   5000 р.
# 67             ЛДЦ МИБС им. С.М. Березина на Костюшко
# 69                            Ревизия органов мошонки  20000 р.

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                                 Центр  \
# 0           Евромед Ин Витро на Суворовском проспекте
# 1                    Евромед на Суворовском проспекте
# 2                         СМТ на Московском проспекте
# 3                           СМТ на Римского-Корсакова
# 4                            СМТ на Валерия Гаврилина
# 5                    Американская медицинская клиника
# 6                           Согаз на Малой Конюшенной
# 7                                    РАМИ на Кирочной
# 8       Европейский Институт Здоровья Семьи на Ленина
# 9       Европейский Институт Здоровья Семьи в Колпино
# 10                                     АМДЦ на Орбели
# 11                                     АМДЦ на Орбели
# 12  ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Ак. Лебедева
# 13       ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Оптиков
# 14                Клиническая больница Святителя Луки
# 15  Александровская больница на проспекте Солидарн...
# 16     НИИ фтизиопульмонологии СПб на Политехнической
# 17            Дорожная клиническая больница ОАО «РЖД»
# 18       Ленинградская областная клиническая больница
# 19  НИИ фтизиопульмонологии СПб на Лиговском просп...
# 20               МСЧ МВД России на проспекте Культуры
# 21              ЛДЦ МИБС им. С.М. Березина в Песочном
# 22                               МСЧ №70 на Комсомола
# 23             ЛДЦ МИБС им. С.М. Березина на Костюшко
#
#                                                Услуга      Цена
# 0   Ревизия органов мошонки/биопсия яичка/придатка...  24500 р.
# 1   Ревизия органов мошонки/биопсия яичка/придатка...  24500 р.
# 2                  Ревизия органов мошонки при травме   9200 р.
# 3                  Ревизия органов мошонки при травме   9200 р.
# 4                  Ревизия органов мошонки при травме   9200 р.
# 5                             Ревизия органов мошонки  17600 р.
# 6                             Ревизия органов мошонки  14420 р.
# 7                  Ревизия органов мошонки при травме  26300 р.
# 8                                     Ревизия мошонки  15000 р.
# 9                                     Ревизия мошонки  15000 р.
# 10                    Ревизия мошонки с одной стороны  12000 р.
# 11                      Двухсторонняя ревизия мошонки  14000 р.
# 12            Ревизия органов мошонки (односторонняя)  10100 р.
# 13            Ревизия органов мошонки (односторонняя)  10100 р.
# 14                        Ревизия мошонки при травмах  41950 р.
# 15                                    Ревизия мошонки  22400 р.
# 16                                    Ревизия мошонки   5500 р.
# 17                                    Ревизия мошонки   7500 р.
# 18                                    Ревизия мошонки  11100 р.
# 19                                    Ревизия мошонки   5500 р.
# 20                                    Ревизия мошонки   5000 р.
# 21                            Ревизия органов мошонки  20000 р.
# 22                                    Ревизия мошонки   5000 р.
# 23                            Ревизия органов мошонки  20000 р.

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new.to_excel('цены_' + file_excel, index=False)
