# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование      цена
# 0                                ИнтраМед на Савушкина
# 2                                      Эпидидимэктомия  23000 р.
# 3    Клиника им. Н.И. Пирогова на Васильевском Острове
# 5                                      Эпидидимэктомия  31680 р.
# 6               Клиника Нарвская на Нарвском проспекте
# ..                                                 ...       ...
# 131                            Удаление придатка яичка   3000 р.
# 132                          Клиника им. Э.Э.Эйхвальда
# 134                         Эпидидимэктомия, 1 сторона   4000 р.
# 135    ДГБ № 2 Св. Марии Магдалины на 2-ой линии В. О.
# 137                            Удаление придатка яичка  11880 р.
#
# [92 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                                 Центр  \
# 0                               ИнтраМед на Савушкина
# 1   Клиника им. Н.И. Пирогова на Васильевском Острове
# 2              Клиника Нарвская на Нарвском проспекте
# 3                         СМТ на Московском проспекте
# 4                           СМТ на Римского-Корсакова
# 5                            СМТ на Валерия Гаврилина
# 6                       ЛамиМед на проспекте Культуры
# 7                              МСЧ №157 на Варшавской
# 8                            Моя Клиника на Гороховой
# 9                           Моя Клиника на Варшавской
# 10                            Скандинавия на Ильюшина
# 11                              ЛИЦ на 2-ой Советской
# 12                    Адмиралтейские Верфи на Садовой
# 13                           MedSwiss на Гаккелевской
# 14                Альфа медика на Ленинском проспекте
# 15                        ЛИЦ на Московском проспекте
# 16      Европейский Институт Здоровья Семьи на Ленина
# 17                   Санкт-Петербургская больница РАН
# 18                            МЦ На Сенной на Ефимова
# 19                               БалтЗдрав на Дыбенко
# 20                       Клиника имени Петра Великого
# 21      Европейский Институт Здоровья Семьи в Колпино
# 22                       БалтЗдрав на Ярослава Гашека
# 23                            Лека-Фарм в Сестрорецке
# 24                 БалтЗдрав на Гражданском проспекте
# 25                      БалтЗдрав на Маршала Говорова
# 26                             Лека-Фарм на Тамбасова
# 27                            АндроМеда на Ординарной
# 28                             Лека-Фарм на Савушкина
# 29              Клиника Здоровья Семьи на Декабристов
# 30                        АндроМеда на Звенигородской
# 31                       МЦ ЛИЦ на Нарвском проспекте
# 32                           Моя Клиника в Кингисеппе
# 33  ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Ак. Лебедева
# 34       ВЦЭиРМ им. А.М. Никифорова МЧС РФ на Оптиков
# 35                Клиническая больница Святителя Луки
# 36         Военно-медицинская академия им. С.М.Кирова
# 37                         ГКБ №31 в Санкт-Петербурге
# 38     НИИ фтизиопульмонологии СПб на Политехнической
# 39            Дорожная клиническая больница ОАО «РЖД»
# 40       Ленинградская областная клиническая больница
# 41  НИИ фтизиопульмонологии СПб на Лиговском просп...
# 42              ЛДЦ МИБС им. С.М. Березина в Песочном
# 43                               МСЧ №70 на Комсомола
# 44                          Клиника им. Э.Э.Эйхвальда
# 45    ДГБ № 2 Св. Марии Магдалины на 2-ой линии В. О.
#
#                                           Услуга      Цена
# 0                                Эпидидимэктомия  23000 р.
# 1                                Эпидидимэктомия  31680 р.
# 2         Эпидидимэктомия под местной анестезией  12000 р.
# 3                                Эпидидимэктомия  20000 р.
# 4                                Эпидидимэктомия  20000 р.
# 5                                Эпидидимэктомия  20000 р.
# 6                                Эпидидимэктомия  22900 р.
# 7                        Удаление придатка яичка  12000 р.
# 8                        Удаление придатка яичка  12000 р.
# 9                        Удаление придатка яичка  12000 р.
# 10                                 Эпидидэктомия  20800 р.
# 11        Эпидидимэктомия под местной анестезией  12000 р.
# 12                               Эпидидимэктомия  25300 р.
# 13                                    Орхэктомия  24600 р.
# 14                               Эпидидимэктомия  30000 р.
# 15        Эпидидимэктомия под местной анестезией  12000 р.
# 16                       Удаление придатка яичка  15000 р.
# 17                               Эпидидимэктомия  10000 р.
# 18        Эпидидимэктомия под местной анестезией  12000 р.
# 19                               Эпидидимэктомия  17440 р.
# 20                    Эпидидимэктомия, 1 сторона   4000 р.
# 21                       Удаление придатка яичка  15000 р.
# 22                               Эпидидимэктомия  17440 р.
# 23                               Эпидидимэктомия  15000 р.
# 24                               Эпидидимэктомия  17440 р.
# 25                               Эпидидимэктомия  17440 р.
# 26                               Эпидидимэктомия  15000 р.
# 27                               Эпидидимэктомия  16500 р.
# 28                               Эпидидимэктомия  15000 р.
# 29  Операции на органах мошонки: эпидидимэктомия  15400 р.
# 30                               Эпидидимэктомия  16500 р.
# 31        Эпидидимэктомия под местной анестезией  12000 р.
# 32                       Удаление придатка яичка  12000 р.
# 33             Эпидидимэктомия (с одной стороны)  15500 р.
# 34             Эпидидимэктомия (с одной стороны)  15500 р.
# 35                               Эпидидимэктомия  30000 р.
# 36                       Удаление придатка яичка   4900 р.
# 37     Иссечение яичка (удаление придатка яичка)  10500 р.
# 38                       Удаление придатка яичка   6200 р.
# 39                               Эпидидимэктомия   7500 р.
# 40                       Удаление придатка яичка  11100 р.
# 41                       Удаление придатка яичка   6200 р.
# 42                       Удаление придатка яичка  20000 р.
# 43                       Удаление придатка яичка   3000 р.
# 44                    Эпидидимэктомия, 1 сторона   4000 р.
# 45                       Удаление придатка яичка  11880 р.

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new[['Центр', 'Цена', 'Услуга']].to_excel('цены_' + file_excel, index=False)
