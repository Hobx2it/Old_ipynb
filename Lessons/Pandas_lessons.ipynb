# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %matplotlib inline

# %%
data = pd.read_excel(r'C:\Users\AmanovRA\Anaconda3\Work-work\Parsings\Балтздрав\Baltzdrav_' + str(datetime.date(datetime.today())) + '.xlsx')

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
plt.style.use('ggplot')  # Красивые графики
plt.rcParams['figure.figsize'] = (15, 5)  # Размер картинок

# %%
data[data['Цена в рублях'] < 6000]['Цена в рублях'].hist()

# %%
data['Цена в рублях'].plot()

# %%
first_ten_prices = data['Цена в рублях'].value_counts()[:10]

# %%
first_ten_prices.plot(kind='bar')

# %%
# !wget https://pythonru.com/downloads/pandas_tutorial_read.csv   # для загрузки файла из веба, непонятно как работает на сервере
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
pandas_tutorial_read = open('pandas_tutorial_read.csv', 'w', encoding='utf8')
pandas_tutorial_read.write('''animal,uniq_id,water_need
elephant,1001,500
elephant,1002,600
elephant,1003,550
tiger,1004,300
tiger,1005,320
tiger,1006,330
tiger,1007,290
tiger,1008,310
zebra,1009,200
zebra,1010,220
zebra,1011,240
zebra,1012,230
zebra,1013,220
zebra,1014,100
zebra,1015,80
lion,1016,420
lion,1017,600
lion,1018,500
lion,1019,390
kangaroo,1020,410
kangaroo,1021,430
kangaroo,1022,410''')
pandas_tutorial_read.close()

# %%
zoo = pd.read_csv('pandas_tutorial_read.csv')

# %%
zoo
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3      tiger     1004         300
# 4      tiger     1005         320
# 5      tiger     1006         330
# 6      tiger     1007         290
# 7      tiger     1008         310
# 8      zebra     1009         200
# 9      zebra     1010         220
# 10     zebra     1011         240
# 11     zebra     1012         230
# 12     zebra     1013         220
# 13     zebra     1014         100
# 14     zebra     1015          80
# 15      lion     1016         420
# 16      lion     1017         600
# 17      lion     1018         500
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 20  kangaroo     1021         430
# 21  kangaroo     1022         410

# %%
data = pd.read_csv(
    'https://pythonru.com/downloads/pandas_tutorial_read.csv',
    delimiter=';', 
    names=['my_datetime', 'event', 'country', 
           'user_id', 'source', 'topic']
)

# %%
data
# Out:
#               my_datetime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# ...                   ...   ...        ...         ...      ...            ...
# 1790  2018-01-01 23:57:14  read  country_2  2458153051  AdWords  North America
# 1791  2018-01-01 23:58:33  read  country_8  2458153052      SEO           Asia
# 1792  2018-01-01 23:59:36  read  country_6  2458153053   Reddit           Asia
# 1793  2018-01-01 23:59:36  read  country_7  2458153054  AdWords         Europe
# 1794  2018-01-01 23:59:38  read  country_5  2458153055   Reddit           Asia
#
# [1795 rows x 6 columns]

# %%
data.loc[:, data.columns.str.contains('coun')]
# Out:
#         country
# 0     country_7
# 1     country_7
# 2     country_7
# 3     country_7
# 4     country_8
# ...         ...
# 1790  country_2
# 1791  country_8
# 1792  country_6
# 1793  country_7
# 1794  country_5
#
# [1795 rows x 1 columns]

# %%
data.iloc[:100, :]
# Out:
#             my_datetime event    country     user_id   source          topic
# 0   2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1   2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2   2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3   2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4   2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# ..                  ...   ...        ...         ...      ...            ...
# 95  2018-01-01 01:23:44  read  country_6  2458151356   Reddit         Africa
# 96  2018-01-01 01:23:44  read  country_7  2458151357  AdWords           Asia
# 97  2018-01-01 01:24:49  read  country_2  2458151358      SEO  North America
# 98  2018-01-01 01:28:30  read  country_4  2458151359      SEO           Asia
# 99  2018-01-01 01:29:05  read  country_2  2458151360  AdWords         Europe
#
# [100 rows x 6 columns]

# %%
data.query('source == "SEO"')
# Out:
#               my_datetime event    country     user_id source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261    SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262    SEO  South America
# 11    2018-01-01 00:08:57  read  country_7  2458151272    SEO      Australia
# 15    2018-01-01 00:11:22  read  country_7  2458151276    SEO  North America
# 16    2018-01-01 00:13:05  read  country_8  2458151277    SEO  North America
# ...                   ...   ...        ...         ...    ...            ...
# 1772  2018-01-01 23:45:58  read  country_7  2458153033    SEO  South America
# 1777  2018-01-01 23:49:52  read  country_5  2458153038    SEO  North America
# 1779  2018-01-01 23:51:25  read  country_4  2458153040    SEO  South America
# 1784  2018-01-01 23:54:03  read  country_2  2458153045    SEO  North America
# 1791  2018-01-01 23:58:33  read  country_8  2458153052    SEO           Asia
#
# [346 rows x 6 columns]

# %%
data[data.source == 'SEO']
# Out:
#               my_datetime event    country     user_id source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261    SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262    SEO  South America
# 11    2018-01-01 00:08:57  read  country_7  2458151272    SEO      Australia
# 15    2018-01-01 00:11:22  read  country_7  2458151276    SEO  North America
# 16    2018-01-01 00:13:05  read  country_8  2458151277    SEO  North America
# ...                   ...   ...        ...         ...    ...            ...
# 1772  2018-01-01 23:45:58  read  country_7  2458153033    SEO  South America
# 1777  2018-01-01 23:49:52  read  country_5  2458153038    SEO  North America
# 1779  2018-01-01 23:51:25  read  country_4  2458153040    SEO  South America
# 1784  2018-01-01 23:54:03  read  country_2  2458153045    SEO  North America
# 1791  2018-01-01 23:58:33  read  country_8  2458153052    SEO           Asia
#
# [346 rows x 6 columns]

# %%
data.loc[data.source == 'SEO']
# Out:
#               my_datetime event    country     user_id source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261    SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262    SEO  South America
# 11    2018-01-01 00:08:57  read  country_7  2458151272    SEO      Australia
# 15    2018-01-01 00:11:22  read  country_7  2458151276    SEO  North America
# 16    2018-01-01 00:13:05  read  country_8  2458151277    SEO  North America
# ...                   ...   ...        ...         ...    ...            ...
# 1772  2018-01-01 23:45:58  read  country_7  2458153033    SEO  South America
# 1777  2018-01-01 23:49:52  read  country_5  2458153038    SEO  North America
# 1779  2018-01-01 23:51:25  read  country_4  2458153040    SEO  South America
# 1784  2018-01-01 23:54:03  read  country_2  2458153045    SEO  North America
# 1791  2018-01-01 23:58:33  read  country_8  2458153052    SEO           Asia
#
# [346 rows x 6 columns]

# %%
data.query('country == "country_2"').loc[:, ['user_id', 'country', 'topic']].head()
# Out:
#        user_id    country   topic
# 6   2458151267  country_2  Europe
# 13  2458151274  country_2  Europe
# 17  2458151278  country_2    Asia
# 19  2458151280  country_2    Asia
# 20  2458151281  country_2    Asia

# %%
zoo_group = zoo.groupby('animal').agg({'uniq_id' : 'count', 'water_need' : ['sum', 'mean', 'median']})#.rename(columns={'uniq_id' : 'cnt', 'water_need' : 'water_need_sum'})

# %%
zoo_group['water_need']
# Out:
#            sum        mean  median
# animal
# elephant  1650  550.000000     550
# kangaroo  1250  416.666667     410
# lion      1910  477.500000     460
# tiger     1550  310.000000     310
# zebra     1290  184.285714     220

# %%
zoo.animal.hist()

# %%
zoo.water_need.hist()

# %%
zoo_eats = open('zoo_eats.csv', 'w', encoding='utf8')
zoo_eats.write('''animal;food
elephant;vegetables
tiger;meat
kangaroo;vegetables
zebra;vegetables
giraffe;vegetables''')
zoo_eats.close()
zoo_eats = pd.read_csv('zoo_eats.csv', delimiter=';')

# %%
zoo_eats
# Out:
#      animal        food
# 0  elephant  vegetables
# 1     tiger        meat
# 2  kangaroo  vegetables
# 3     zebra  vegetables
# 4   giraffe  vegetables

# %%
zoo = zoo.merge(zoo_eats, how='left')

# %%
zoo
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant     1001         500  vegetables
# 1   elephant     1002         600  vegetables
# 2   elephant     1003         550  vegetables
# 3      tiger     1004         300        meat
# 4      tiger     1005         320        meat
# 5      tiger     1006         330        meat
# 6      tiger     1007         290        meat
# 7      tiger     1008         310        meat
# 8      zebra     1009         200  vegetables
# 9      zebra     1010         220  vegetables
# 10     zebra     1011         240  vegetables
# 11     zebra     1012         230  vegetables
# 12     zebra     1013         220  vegetables
# 13     zebra     1014         100  vegetables
# 14     zebra     1015          80  vegetables
# 15      lion     1016         420         NaN
# 16      lion     1017         600         NaN
# 17      lion     1018         500         NaN
# 18      lion     1019         390         NaN
# ...

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")

# Prepare data
x_var = 'manufacturer'
groupby_var = 'class'
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]

# Draw
plt.figure(figsize=(16,9), dpi= 80)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = plt.hist(vals, df[x_var].unique().__len__(), stacked=True, density=False, color=colors[:len(vals)])

# Decoration
plt.legend({group:col for group, col in zip(np.unique(df[groupby_var]).tolist(), colors[:len(vals)])})
plt.title(f"Stacked Histogram of ${x_var}$ colored by ${groupby_var}$", fontsize=22)
plt.xlabel(x_var)
plt.ylabel("Frequency")
plt.ylim(0, 40)
plt.xticks(ticks=bins, labels=np.unique(df[x_var]).tolist(), rotation=90, horizontalalignment='left')
plt.show()

# %%
vals
# Out:
# [['chevrolet', 'chevrolet', 'chevrolet', 'chevrolet', 'chevrolet'],
#  ['audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'nissan',
#   'nissan',
#   'subaru',
#   'subaru',
#   'subaru',
#   'subaru',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen'],
#  ['audi',
#   'audi',
#   'audi',
#   'chevrolet',
#   'chevrolet',
#   'chevrolet',
#   'chevrolet',
#   'chevrolet',
#   'hyundai',
#   'hyundai',
#   'hyundai',
#   'hyundai',
#   'hyundai',
#   'hyundai',
#   'hyundai',
#   'nissan',
# ...

# %%
x_var = 'Год первого посещения клиента'
groupby_var = 'class'
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]

# Draw
plt.figure(figsize=(16,9), dpi= 80)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = plt.hist(vals, df[x_var].unique().__len__(), stacked=True, density=False, color=colors[:len(vals)])

# Decoration
plt.legend({group:col for group, col in zip(np.unique(df[groupby_var]).tolist(), colors[:len(vals)])})
plt.title(f"Stacked Histogram of ${x_var}$ colored by ${groupby_var}$", fontsize=22)
plt.xlabel(x_var)
plt.ylabel("Frequency")
plt.ylim(0, 40)
plt.xticks(ticks=bins, labels=np.unique(df[x_var]).tolist(), rotation=90, horizontalalignment='left')
plt.show()

# %%
for i, df in df_agg:
    print(df)
# Out:
#    manufacturer    class
# 23    chevrolet  2seater
# 24    chevrolet  2seater
# 25    chevrolet  2seater
# 26    chevrolet  2seater
# 27    chevrolet  2seater
#     manufacturer    class
# 0           audi  compact
# 1           audi  compact
# 2           audi  compact
# 3           audi  compact
# 4           audi  compact
# 5           audi  compact
# 6           audi  compact
# 7           audi  compact
# 8           audi  compact
# 9           audi  compact
# 10          audi  compact
# 11          audi  compact
# 12          audi  compact
# 13          audi  compact
# 14          audi  compact
# 141       nissan  compact
# 142       nissan  compact
# 169       subaru  compact
# 170       subaru  compact
# 171       subaru  compact
# 172       subaru  compact
# 186       toyota  compact
# 187       toyota  compact
# 188       toyota  compact
# 189       toyota  compact
# 190       toyota  compact
# 191       toyota  compact
# 192       toyota  compact
# ...

# %%
vals
# Out:
# [['chevrolet', 'chevrolet', 'chevrolet', 'chevrolet', 'chevrolet'],
#  ['audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'audi',
#   'nissan',
#   'nissan',
#   'subaru',
#   'subaru',
#   'subaru',
#   'subaru',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'toyota',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen',
#   'volkswagen'],
#  ['audi',
#   'audi',
#   'audi',
#   'chevrolet',
#   'chevrolet',
#   'chevrolet',
#   'chevrolet',
#   'chevrolet',
#   'hyundai',
#   'hyundai',
#   'hyundai',
#   'hyundai',
#   'hyundai',
#   'hyundai',
#   'hyundai',
#   'nissan',
# ...

# %%
df[groupby_var].tolist()
# Out:
# ['compact',
#  'compact',
#  'compact',
#  'compact',
#  'compact',
#  'compact',
#  'compact',
#  'compact',
#  'compact',
#  'compact',
#  'compact',
#  'compact',
#  'compact',
#  'compact',
#  'compact',
#  'midsize',
#  'midsize',
#  'midsize',
#  'suv',
#  'suv',
#  'suv',
#  'suv',
#  'suv',
#  '2seater',
#  '2seater',
#  '2seater',
#  '2seater',
#  '2seater',
#  'suv',
#  'suv',
#  'suv',
#  'suv',
#  'midsize',
#  'midsize',
#  'midsize',
#  'midsize',
#  'midsize',
#  'minivan',
#  'minivan',
#  'minivan',
#  'minivan',
#  'minivan',
#  'minivan',
#  'minivan',
#  'minivan',
#  'minivan',
#  'minivan',
#  'minivan',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'suv',
#  'suv',
#  'suv',
#  'suv',
#  'suv',
#  'suv',
#  'suv',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'pickup',
#  'suv',
#  'suv',
#  'suv',
#  'suv',
# ...
