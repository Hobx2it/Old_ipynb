# %%
import pandas as pd
import os

# %%
for file in os.listdir('.'):
    if 'xlsx' in file and '$' not in file:
        file_excel = file

# %%
data = pd.read_excel(file_excel, sheet_name='Лист2', usecols='A:B', names=['наименование', 'цена'], header=None)

data = data.fillna('')
data = data[data['наименование'] != '']

data
# Out:
#                                           наименование      цена
# 0       Клиника Благодатная на проспекте Юрия Гагарина
# 2                    Лигирование геморроидального узла   5000 р.
# 3                        Дезир на проспекте Пархоменко
# 5    Лигирование геморроидального узла усиленным ла...   7000 р.
# 6                              Скандинавия на Ильюшина
# ..                                                 ...       ...
# 320       Удаление геморроидальных узлов (лигирование)   3500 р.
# 321                               МСЧ №70 на Комсомола
# 323                  Лигирование геморроидальных узлов  10000 р.
# 324     Городская больница №9 на Крестовском проспекте
# 326  Эвакуация тромбированных геморроидальных узлов...   6500 р.
#
# [218 rows x 2 columns]

# %%
dct = {'Центр' : [],
      'Услуга' : [], 
      'Цена' : []}

for i in data.index:
    if data['цена'][i] == '':
        temp_centr = data['наименование'][i]
        continue
    dct['Центр'].append(temp_centr)
    dct['Услуга'].append(data['наименование'][i])
    dct['Цена'].append(data['цена'][i])

# %%
data_new  = pd.DataFrame(dct)


data_new
# Out:
#                                                  Центр  \
# 0       Клиника Благодатная на проспекте Юрия Гагарина
# 1                        Дезир на проспекте Пархоменко
# 2                              Скандинавия на Ильюшина
# 3                    СМ-Клиника на Дунайском проспекте
# 4                    СМ-Клиника на проспекте Ударников
# ..                                                 ...
# 104  Александровская больница на проспекте Солидарн...
# 105                             СПГМУ им. И.П. Павлова
# 106                               ГКДЦ №1 на Сикейроса
# 107                               МСЧ №70 на Комсомола
# 108     Городская больница №9 на Крестовском проспекте
#
#                                                 Услуга      Цена
# 0                    Лигирование геморроидального узла   5000 р.
# 1    Лигирование геморроидального узла усиленным ла...   7000 р.
# 2                    Лигирование геморроидального узла   8600 р.
# 3                                   Лигирование 1 узла   6300 р.
# 4                                   Лигирование 1 узла   6300 р.
# ..                                                 ...       ...
# 104  Лигирование геморроидальных узлов латексными к...   3000 р.
# 105  Лигирование внутреннего геморроидального узла,...   6400 р.
# 106       Удаление геморроидальных узлов (лигирование)   3500 р.
# 107                  Лигирование геморроидальных узлов  10000 р.
# 108  Эвакуация тромбированных геморроидальных узлов...   6500 р.
#
# [109 rows x 3 columns]

# %%
def no_suffix(x):
    if ' на ' in x:
        return x[:x.find(' на ')]
    elif ' в ' in x:
        return x[:x.find(' в ')]
    else:
        return x

data_new['Центр'] = data_new['Центр'].apply(no_suffix)
data_new['Цена'] = data_new['Цена'].apply(lambda x: int(x[:x.find(' р')]))

# %%
data_new = data_new.drop_duplicates(subset=['Центр', 'Услуга'])

data_new[['Центр', 'Цена', 'Услуга']].to_excel('цены_' + file_excel, index=False)
